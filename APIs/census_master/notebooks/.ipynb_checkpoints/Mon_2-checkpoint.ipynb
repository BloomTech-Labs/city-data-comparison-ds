# %%
import pandas as pd

# %%
pd.read_csv('zipcode_table.csv')
# Out:
# C:\Users\zebfr\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (2,3,4,6,7,10,11,14,15,18,19,22,23,26,27,30,31,34,35,38,39,42,43,46,47,50,51,54,55,66,67,68,70,71,74,75,78,79,82,83,86,87,90,91,94,95,96,98,99,102,103,106,107,110,111,114,115,118,119,120,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,146,147,170,171,172,174,175,178,179,182,183,186,187,190,191,194,195,196,198,199,202,203,206,207,208,210,211,214,215,218,219,222,223,226,227,230,231,232,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,274,275,276,277,278,279,280,282,283,284,285,286,287,288,290,291,294,295,296,298,299,302,303,304,306,307,310,311,312,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,36
# ...

# %%
pd.read_csv('')

# %%
geo_id = pd.read_csv('geo_id.csv', low_memory=False)

# %%
US = geo_id[geo_id['Country Code'] == 'US']
US
# Out:
#         Criteria ID                Name  \
# 10598       1012873           Anchorage
# 10599       1012874            Anderson
# 10600       1012875              Angoon
# 10601       1012876             Atqasuk
# 10602       1012877           Utqiagvik
# ...             ...                 ...
# 98185       9073538           Eddington
# 102013      9077370               29486
# 102026      9168160          Stokesdale
# 102027      1013729  Desert Hot Springs
# 102028      1021155       Holly Springs
#
#                                            Canonical Name  Parent ID  \
# 10598            Anchorage,Anchorage,Alaska,United States    21132.0
# 10599                       Anderson,Alaska,United States    21132.0
# 10600                         Angoon,Alaska,United States    21132.0
# 10601                        Atqasuk,Alaska,United States    21132.0
# 10602                      Utqiagvik,Alaska,United States    21132.0
# ...

# %%
city = US[US['Target Type'] == 'City']
city
# Out:
#         Criteria ID               Name  \
# 10598       1012873          Anchorage
# 10599       1012874           Anderson
# 10600       1012875             Angoon
# 10601       1012876            Atqasuk
# 10602       1012877          Utqiagvik
# ...             ...                ...
# 98179       9073532       North Canaan
# 98184       9073537  Cornwells Heights
# 98185       9073538          Eddington
# 102026      9168160         Stokesdale
# 102028      1021155      Holly Springs
#
#                                       Canonical Name  Parent ID Country Code  \
# 10598       Anchorage,Anchorage,Alaska,United States    21132.0           US
# 10599                  Anderson,Alaska,United States    21132.0           US
# 10600                    Angoon,Alaska,United States    21132.0           US
# 10601                   Atqasuk,Alaska,United States    21132.0           US
# 10602                 Utqiagvik,Alaska,United States    21132.0           US
# ...
