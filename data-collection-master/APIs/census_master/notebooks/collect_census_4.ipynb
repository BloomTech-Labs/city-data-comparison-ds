# %%
import pandas as pd

# %%
df_at = pd.read_csv('data/all_tables.csv',low_memory=False)

# %%
df_at.shape
# Out:
# (58369, 2093)

# %%
cenesus_column_headers = pd.read_csv('https://raw.githubusercontent.com/Lambda-School-Labs/city-data-comparison-ds/master/data-help/census-columns.csv')

# %%
print(cenesus_column_headers.shape)
cenesus_column_headers.head(100)
#88
# Out:
# (381, 1)
#    column_headers
# 0      DP02_0001E
# 1      DP02_0002E
# 2     DP02_0002PE
# 3     DP02_0004PE
# 4      DP02_0017E
# ..            ...
# 95    DP03_0020PE
# 96    DP03_0021PE
# 97    DP03_0022PE
# 98    DP03_0023PE
# 99    DP03_0024PE
#
# [100 rows x 1 columns]

# %%
cenesus_column_headers.head()
# Out:
#   column_headers
# 0     DP02_0001E
# 1     DP02_0002E
# 2    DP02_0002PE
# 3    DP02_0004PE
# 4     DP02_0017E

# %%
##the = {'column_headers':'GEO_ID'}
next_yea = {'column_headers':'NAME'} 
#new_thing2 = cenesus_column_headers.append(the, ignore_index=True)
new_thing3 = new_thing2.append(next_yea, ignore_index=True)

# %%
new_thing3
# Out:
#     column_headers
# 0       DP02_0001E
# 1       DP02_0002E
# 2      DP02_0002PE
# 3      DP02_0004PE
# 4       DP02_0017E
# ..             ...
# 378     DP05_0087E
# 379    DP05_0088PE
# 380    DP05_0089PE
# 381         GEO_ID
# 382           NAME
#
# [383 rows x 1 columns]

# %%
#name = ['NAME'] 

those_the = new_thing3.values.tolist()
#first = these.append(the)
#second = first.append(name)

# %%
those_the
# Out:
# [['DP02_0001E'],
#  ['DP02_0002E'],
#  ['DP02_0002PE'],
#  ['DP02_0004PE'],
#  ['DP02_0017E'],
#  ['DP02_0024E'],
#  ['DP02_0025PE'],
#  ['DP02_0026PE'],
#  ['DP02_0027PE'],
#  ['DP02_0029PE'],
#  ['DP02_0030E'],
#  ['DP02_0031PE'],
#  ['DP02_0032PE'],
#  ['DP02_0033PE'],
#  ['DP02_0035PE'],
#  ['DP02_0036E'],
#  ['DP02_0036M'],
#  ['DP02_0037PE'],
#  ['DP02_0039E'],
#  ['DP02_0040E'],
#  ['DP02_0041E'],
#  ['DP02_0042E'],
#  ['DP02_0052E'],
#  ['DP02_0052PE'],
#  ['DP02_0053PE'],
#  ['DP02_0054PE'],
#  ['DP02_0055PE'],
#  ['DP02_0056PE'],
#  ['DP02_0057PE'],
#  ['DP02_0058E'],
#  ['DP02_0059PE'],
#  ['DP02_0060PE'],
#  ['DP02_0061PE'],
#  ['DP02_0062PE'],
#  ['DP02_0063PE'],
#  ['DP02_0064PE'],
#  ['DP02_0065PE'],
#  ['DP02_0066PE'],
#  ['DP02_0067PE'],
#  ['DP02_0069E'],
#  ['DP02_0069PE'],
#  ['DP02_0071E'],
#  ['DP02_0071PE'],
#  ['DP02_0078E'],
#  ['DP02_0078PE'],
#  ['DP02_0084E'],
#  ['DP02_0084PE'],
#  ['DP02_0085E'],
#  ['DP02_0085PE'],
#  ['DP02_0087PE'],
# ...

# %%
those_the_super = [item[0] for item in those_the]
those_the_super
# Out:
# ['DP02_0001E',
#  'DP02_0002E',
#  'DP02_0002PE',
#  'DP02_0004PE',
#  'DP02_0017E',
#  'DP02_0024E',
#  'DP02_0025PE',
#  'DP02_0026PE',
#  'DP02_0027PE',
#  'DP02_0029PE',
#  'DP02_0030E',
#  'DP02_0031PE',
#  'DP02_0032PE',
#  'DP02_0033PE',
#  'DP02_0035PE',
#  'DP02_0036E',
#  'DP02_0036M',
#  'DP02_0037PE',
#  'DP02_0039E',
#  'DP02_0040E',
#  'DP02_0041E',
#  'DP02_0042E',
#  'DP02_0052E',
#  'DP02_0052PE',
#  'DP02_0053PE',
#  'DP02_0054PE',
#  'DP02_0055PE',
#  'DP02_0056PE',
#  'DP02_0057PE',
#  'DP02_0058E',
#  'DP02_0059PE',
#  'DP02_0060PE',
#  'DP02_0061PE',
#  'DP02_0062PE',
#  'DP02_0063PE',
#  'DP02_0064PE',
#  'DP02_0065PE',
#  'DP02_0066PE',
#  'DP02_0067PE',
#  'DP02_0069E',
#  'DP02_0069PE',
#  'DP02_0071E',
#  'DP02_0071PE',
#  'DP02_0078E',
#  'DP02_0078PE',
#  'DP02_0084E',
#  'DP02_0084PE',
#  'DP02_0085E',
#  'DP02_0085PE',
#  'DP02_0087PE',
#  'DP02_0088PE',
#  'DP02_0089PE',
#  'DP02_0090PE',
#  'DP02_0092PE',
#  'DP02_0111PE',
#  'DP02_0112PE',
# ...

# %%
df_ats = df_at[those_the_super]

# %%
df_ats
# Out:
#       DP02_0001E DP02_0002E DP02_0002PE DP02_0004PE DP02_0017E DP02_0024E  \
# 1             88         26        29.5        29.5        218         55
# 2            993        614        61.8        41.8       2405       1148
# 3           1472       1061        72.1        47.7       4346       1573
# 4            308        180        58.4        43.5        641        282
# 5            117         60        51.3        34.2        290        120
# ...          ...        ...         ...         ...        ...        ...
# 58364        NaN        NaN         NaN         NaN        NaN        NaN
# 58365        NaN        NaN         NaN         NaN        NaN        NaN
# 58366        NaN        NaN         NaN         NaN        NaN        NaN
# 58367        NaN        NaN         NaN         NaN        NaN        NaN
# 58368        NaN        NaN         NaN         NaN        NaN        NaN
#
#       DP02_0025PE DP02_0026PE DP02_0027PE DP02_0029PE  ... DP05_0081PE  \
# ...

# %%
df_ats = df_ats.drop(index = 0)

# %%
df= df_ats

# %%
# Make a new column with just the state name
df['State'] = df_ats['NAME'].str.split(",", n = 1, expand=True)[1]
df['State'] = df_ats['State'].str.lstrip()

# Make a new column with just the city name
df['City'] = df_ats['NAME'].str.split(",", n = 1, expand=True)[0]

# Make a new column with just the state name
df['State'] = df_ats['NAME'].str.split(",", n = 1, expand=True)[1]
df['State'] = df_ats['State'].str.lstrip()

# Mark which type of 'place' each city is deamded to be by the US Census Bureau
df['Place_Type_city'] = df_ats['City'].str.contains(pat = ' city')
df['Place_Type_town'] = df_ats['City'].str.contains(pat = ' town')
df['Place_Type_borough'] = df_ats['City'].str.contains(pat = ' borough')
df['Place_Type_CPD'] = df_ats['City'].str.contains(pat = ' CDP')

# Remove that place type from the city name
df['City'] = df_ats['City'].str.replace(' city', '', regex=False)
df['City'] = df_ats['City'].str.replace(' town', '', regex=False)
df['City'] = df_ats['City'].str.replace(' borough', '', regex=False)
df['City'] = df_ats['City'].str.replace(' CDP', '', regex=False)
df['City'] = df_ats['City'].str.rstrip()

# %%
df['City'] = df_ats['City'].str.replace('zona urbana', '', regex=False)
df['City'] = df_ats['City'].str.replace(' comunidad', '', regex=False)

# %%
df[['City','NAME']]
# Out:
#              City                               NAME
# 1          Abanda                Abanda CDP, Alabama
# 2       Abbeville            Abbeville city, Alabama
# 3      Adamsville           Adamsville city, Alabama
# 4         Addison              Addison town, Alabama
# 5           Akron                Akron town, Alabama
# ...           ...                                ...
# 58364    Vieques    Vieques zona urbana, Puerto Rico
# 58365   Villalba   Villalba zona urbana, Puerto Rico
# 58366    Yabucoa    Yabucoa zona urbana, Puerto Rico
# 58367      Yauco      Yauco zona urbana, Puerto Rico
# 58368      Yaurel      Yaurel comunidad, Puerto Rico
#
# [58368 rows x 2 columns]

# %%
df
# Out:
#       DP02_0001E DP02_0002E DP02_0002PE DP02_0004PE DP02_0017E DP02_0024E  \
# 1             88         26        29.5        29.5        218         55
# 2            993        614        61.8        41.8       2405       1148
# 3           1472       1061        72.1        47.7       4346       1573
# 4            308        180        58.4        43.5        641        282
# 5            117         60        51.3        34.2        290        120
# ...          ...        ...         ...         ...        ...        ...
# 58364        NaN        NaN         NaN         NaN        NaN        NaN
# 58365        NaN        NaN         NaN         NaN        NaN        NaN
# 58366        NaN        NaN         NaN         NaN        NaN        NaN
# 58367        NaN        NaN         NaN         NaN        NaN        NaN
# 58368        NaN        NaN         NaN         NaN        NaN        NaN
#
#       DP02_0025PE DP02_0026PE DP02_0027PE DP02_0029PE  ... DP05_0088PE  \
# ...

# %%
'''
#uscb = uscb.drop(index = 0) # drop first row

# Make a new column with just the city name
uscb['City'] = uscb['NAME'].str.split(",", n = 1, expand=True)[0]

# Make a new column with just the state name
uscb['State'] = uscb['NAME'].str.split(",", n = 1, expand=True)[1]
uscb['State'] = uscb['State'].str.lstrip()

# Make a new column with just the city name
uscb['City'] = uscb['NAME'].str.split(",", n = 1, expand=True)[0]

# Make a new column with just the state name
uscb['State'] = uscb['NAME'].str.split(",", n = 1, expand=True)[1]
uscb['State'] = uscb['State'].str.lstrip()

# Mark which type of 'place' each city is deamded to be by the US Census Bureau
uscb['Place_Type_city'] = uscb['City'].str.contains(pat = ' city')
uscb['Place_Type_town'] = uscb['City'].str.contains(pat = ' town')
uscb['Place_Type_borough'] = uscb['City'].str.contains(pat = ' borough')
uscb['Place_Type_CPD'] = uscb['City'].str.contains(pat = ' CDP')

# Remove that place type from the city name
uscb['City'] = uscb['City'].str.replace(' city', '', regex=False)
uscb['City'] = uscb['City'].str.replace(' town', '', regex=False)
uscb['City'] = uscb['City'].str.replace(' borough', '', regex=False)
uscb['City'] = uscb['City'].str.replace(' CDP', '', regex=False)
uscb['City'] = uscb['City'].str.rstrip()
'''
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
# Make a state abbrevations column with the dictionary above
df['State_Abbrev'] = df_ats['State'].map(us_state_abbrev)

# Make the column we'll use as the primary key to match up datasets, City_ST
df['City_ST'] = df_ats['City'] + " " + df_ats['State_Abbrev']

# %%
df
# Out:
#       DP02_0001E DP02_0002E DP02_0002PE DP02_0004PE DP02_0017E DP02_0024E  \
# 1             88         26        29.5        29.5        218         55
# 2            993        614        61.8        41.8       2405       1148
# 3           1472       1061        72.1        47.7       4346       1573
# 4            308        180        58.4        43.5        641        282
# 5            117         60        51.3        34.2        290        120
# ...          ...        ...         ...         ...        ...        ...
# 58364        NaN        NaN         NaN         NaN        NaN        NaN
# 58365        NaN        NaN         NaN         NaN        NaN        NaN
# 58366        NaN        NaN         NaN         NaN        NaN        NaN
# 58367        NaN        NaN         NaN         NaN        NaN        NaN
# 58368        NaN        NaN         NaN         NaN        NaN        NaN
#
#       DP02_0025PE DP02_0026PE DP02_0027PE DP02_0029PE  ...            GEO_ID  \
# ...

# %%
dup = df['NAME'].nunique() - df['City_ST'].nunique()
dup
# Out:
# 77

# %%
((df_clean.City_ST.value_counts() > 1) == False).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-943743a48c18> in <module>
# ----> 1 ((df_clean.City_ST.value_counts() > 1) == False).sum()
#
# NameError: name 'df_clean' is not defined

# %%
df_dirt
# Out:
# [Mountain Park GA       True
#  Rice Lake MN           True
#  Belle Haven VA         True
#  Fairview NJ            True
#  Bel Air MD             True
#                        ...
#  Tamaqua PA            False
#  Honokaa HI            False
#  West Bishop CA        False
#  Flintstone MD         False
#  Detroit village IL    False
#  Name: City_ST, Length: 29496, dtype: bool]

# %%
df_clean = df.drop_duplicates()

# %%
df_clean.duplicated().value_counts().sum()
# Out:
# 29573

# %%
df
# Out:
#       DP02_0001E DP02_0002E DP02_0002PE DP02_0004PE DP02_0017E DP02_0024E  \
# 1             88         26        29.5        29.5        218         55
# 2            993        614        61.8        41.8       2405       1148
# 3           1472       1061        72.1        47.7       4346       1573
# 4            308        180        58.4        43.5        641        282
# 5            117         60        51.3        34.2        290        120
# ...          ...        ...         ...         ...        ...        ...
# 58364        NaN        NaN         NaN         NaN        NaN        NaN
# 58365        NaN        NaN         NaN         NaN        NaN        NaN
# 58366        NaN        NaN         NaN         NaN        NaN        NaN
# 58367        NaN        NaN         NaN         NaN        NaN        NaN
# 58368        NaN        NaN         NaN         NaN        NaN        NaN
#
#       DP02_0025PE DP02_0026PE DP02_0027PE DP02_0029PE  ...            GEO_ID  \
# ...

# %%
test = df_clean[df_clean.City_ST == 'Bostonia']
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d0b6d4a7cad> in <module>
# ----> 1 test = df_clean[df_clean.City_ST == 'Bostonia']
#       2 test
#
# NameError: name 'df_clean' is not defined

# %%
CPD = df_clean[df_clean.Place_Type_CPD == True]  
print(CPD.shape)
CPD
# Out:
# (9800, 391)
#       DP02_0001E DP02_0002E DP02_0002PE DP02_0004PE DP02_0017E DP02_0024E  \
# 1             88         26        29.5        29.5        218         55
# 9           1475       1194        80.9        63.6       4000       1408
# 30           435        362        83.2        78.9       1473        523
# 34           490        418        85.3        63.5       1458        522
# 41            46         14        30.4        30.4         76         40
# ...          ...        ...         ...         ...        ...        ...
# 29312          0          0           -           -          0          0
# 29314         53         25        47.2        47.2         99         53
# 29315        696        512        73.6        70.1       1731        750
# 29316         48         27        56.3        56.3        120         62
# 29320         30         30       100.0       100.0         84         39
#
# ...

# %%
borough = df_clean[df_clean.Place_Type_borough == True]  
print(borough.shape)
borough
# Out:
# (1219, 391)
#       DP02_0001E DP02_0002E DP02_0002PE DP02_0004PE DP02_0017E DP02_0024E  \
# 728        12521       7610        60.8        48.2      31699      13546
# 879         3561       2129        59.8        43.5       8456       3632
# 938         1074        650        60.5        47.7       2431       1124
# 3911         362        161        44.5        39.0        735        295
# 3934        1822        980        53.8        30.4       3936       1528
# ...          ...        ...         ...         ...        ...        ...
# 23262        275        237        86.2        58.9        870        315
# 23263        130        101        77.7        63.8        320        143
# 23264        761        520        68.3        49.1       1780        698
# 23265       1420        765        53.9        43.1       2882       1344
# 23267       1805        979        54.2        44.0       3676       1345
#
# ...

# %%
borough = df_clean[df_clean.Place_Type_borough == True]  
print(borough.shape)
borough

CPD = df_clean[df_clean.Place_Type_CPD == True]  
print(CPD.shape)
CPD

# %%
df_clean_cpd = df_clean[df_clean.Place_Type_CPD != True] 
df_extr_clean = df_clean_cpd[df_clean_cpd.Place_Type_borough != True]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-904f1eee7bab> in <module>
#       1 df_clean_cpd = df_clean[df_clean.Place_Type_CPD != True]
#       2 df_extr_clean = df_clean_cpd[df_clean_cpd.Place_Type_borough != True]
# ----> 3 df_extr_clean.shape()
#
# TypeError: 'tuple' object is not callable

# %%
for_real_clean.to_csv(r'C:\Users\zebfr\city-data1\Try_4\data\df_extra_clean.csv')

# %%
df_extr_clean.isnull().sum()
# Out:
# DP02_0001E            253
# DP02_0002E            253
# DP02_0002PE           253
# DP02_0004PE           253
# DP02_0017E            253
#                      ...
# Place_Type_town         0
# Place_Type_borough      0
# Place_Type_CPD          0
# State_Abbrev            2
# City_ST                 2
# Length: 391, dtype: int64

# %%
#df_extr_clean
for_real_clean = df_extr_clean.dropna() 
for_real_clean.isnull().sum()
# Out:
# DP02_0001E            0
# DP02_0002E            0
# DP02_0002PE           0
# DP02_0004PE           0
# DP02_0017E            0
#                      ..
# Place_Type_town       0
# Place_Type_borough    0
# Place_Type_CPD        0
# State_Abbrev          0
# City_ST               0
# Length: 391, dtype: int64
