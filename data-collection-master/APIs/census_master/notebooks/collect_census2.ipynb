# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
all_states2 = pd.read_csv('./data/table2_all.csv', low_memory=False)

# %%
all_states2
# Out:
#                  GEO_ID                               NAME                                      DP02_0001E                                         DP02_0001M                                        DP02_0001PE                                        DP02_0001PM                                         DP02_0002E                                         DP02_0002M                                        DP02_0002PE                                        DP02_0002PM                                         DP02_0003E                                         DP02_0003M                                        DP02_0003PE                                        DP02_0003PM                                         DP02_0004E                                         DP02_0004M                                        DP02_0004PE                                        DP02_0004PM                                         DP02_0005E                                         DP02_0005M  \
# ...

# %%
type(all_states2)
# Out:
# pandas.core.frame.DataFrame

# %%
all_states3 = pd.read_csv('./data/table3_all.csv', low_memory=False)

# %%
all_states3
# Out:
#                  GEO_ID                               NAME                                         DP03_0001E                                         DP03_0001M                                        DP03_0001PE                                        DP03_0001PM                                         DP03_0002E                                         DP03_0002M                                        DP03_0002PE                                        DP03_0002PM                                         DP03_0003E                                         DP03_0003M                                        DP03_0003PE                                        DP03_0003PM                                         DP03_0004E                                         DP03_0004M                                        DP03_0004PE                                        DP03_0004PM                                         DP03_0005E                                         DP03_0005M  \
# ...

# %%
type(all_states3)
# Out:
# pandas.core.frame.DataFrame

# %%
all_states4 = pd.read_csv('./data/table4_all.csv', low_memory=False)
type(all_states4)
# Out:
# pandas.core.frame.DataFrame

# %%
all_states5 = pd.read_csv('./data/table5_all.csv', low_memory=False)
type(all_states5)
# Out:
# pandas.core.frame.DataFrame

# %%
all_tables = pd.concat([all_states2, all_states3, all_states4, all_states5], axis=1)
type(all_tables)
# Out:
# pandas.core.frame.DataFrame

# %%
df_allt = all_tables
all_tables.to_csv(r'C:\Users\zebfr\city-data1\Try_4\data\all_tables.csv')

# %%
all_tables.shape
# Out:
# (58369, 2092)

# %%
all_tables
# Out:
#                  GEO_ID                               NAME                                      DP02_0001E                                         DP02_0001M                                        DP02_0001PE                                        DP02_0001PM                                         DP02_0002E                                         DP02_0002M                                        DP02_0002PE                                        DP02_0002PM                                         DP02_0003E                                         DP02_0003M                                        DP02_0003PE                                        DP02_0003PM                                         DP02_0004E                                         DP02_0004M                                        DP02_0004PE                                        DP02_0004PM                                         DP02_0005E                                         DP02_0005M  \
# ...

# %%
import pandas as pd

# %%
cenesus_column_headers = pd.read_csv('https://raw.githubusercontent.com/Lambda-School-Labs/city-data-comparison-ds/master/data-help/census-columns.csv')

# %%
print(cenesus_column_headers.shape)
cenesus_column_headers.head(100)
#88
# Out:
# (381, 1)
#    column_headers
# 0      DP02_0001E
# 1      DP02_0002E
# 2     DP02_0002PE
# 3     DP02_0004PE
# 4      DP02_0017E
# 5      DP02_0024E
# 6     DP02_0025PE
# 7     DP02_0026PE
# 8     DP02_0027PE
# 9     DP02_0029PE
# 10     DP02_0030E
# 11    DP02_0031PE
# 12    DP02_0032PE
# 13    DP02_0033PE
# 14    DP02_0035PE
# 15     DP02_0036E
# 16     DP02_0036M
# 17    DP02_0037PE
# 18     DP02_0039E
# 19     DP02_0040E
# 20     DP02_0041E
# 21     DP02_0042E
# 22     DP02_0052E
# 23    DP02_0052PE
# 24    DP02_0053PE
# 25    DP02_0054PE
# 26    DP02_0055PE
# 27    DP02_0056PE
# 28    DP02_0057PE
# 29     DP02_0058E
# 30    DP02_0059PE
# 31    DP02_0060PE
# 32    DP02_0061PE
# 33    DP02_0062PE
# 34    DP02_0063PE
# 35    DP02_0064PE
# 36    DP02_0065PE
# 37    DP02_0066PE
# 38    DP02_0067PE
# 39     DP02_0069E
# 40    DP02_0069PE
# 41     DP02_0071E
# 42    DP02_0071PE
# 43     DP02_0078E
# 44    DP02_0078PE
# 45     DP02_0084E
# 46    DP02_0084PE
# 47     DP02_0085E
# ...

# %%
cenesus_column_headers.head()
# Out:
#   column_headers
# 0     DP02_0001E
# 1     DP02_0002E
# 2    DP02_0002PE
# 3    DP02_0004PE
# 4     DP02_0017E

# %%
the = {'column_headers':'GEO_ID'},
next_yea = {'column_headers':'NAME'} 
#new_thing2 = cenesus_column_headers.append(the, ignore_index=True)
new_thing3 = new_thing2.append(next_yea, ignore_index=True)

# %%
new_thing3
# Out:
#     column_headers
# 0       DP02_0001E
# 1       DP02_0002E
# 2      DP02_0002PE
# 3      DP02_0004PE
# 4       DP02_0017E
# ..             ...
# 378     DP05_0087E
# 379    DP05_0088PE
# 380    DP05_0089PE
# 381         GEO_ID
# 382           NAME
#
# [383 rows x 1 columns]

# %%
#name = ['NAME'] 

those_the = cenesus_column_headers.values.tolist()
#first = these.append(the)
#second = first.append(name)

# %%
#those.append(the)

# %%
all_states3
# Out:
#                  GEO_ID                               NAME                                         DP03_0001E                                         DP03_0001M                                        DP03_0001PE                                        DP03_0001PM                                         DP03_0002E                                         DP03_0002M                                        DP03_0002PE                                        DP03_0002PM                                         DP03_0003E                                         DP03_0003M                                        DP03_0003PE                                        DP03_0003PM                                         DP03_0004E                                         DP03_0004M                                        DP03_0004PE                                        DP03_0004PM                                         DP03_0005E                                         DP03_0005M  \
# ...

# %%
all_states2
# Out:
#                  GEO_ID                               NAME                                      DP02_0001E                                         DP02_0001M                                        DP02_0001PE                                        DP02_0001PM                                         DP02_0002E                                         DP02_0002M                                        DP02_0002PE                                        DP02_0002PM                                         DP02_0003E                                         DP02_0003M                                        DP02_0003PE                                        DP02_0003PM                                         DP02_0004E                                         DP02_0004M                                        DP02_0004PE                                        DP02_0004PM                                         DP02_0005E                                         DP02_0005M  \
# ...

# %%
type(these)
# Out:
# list

# %%
those_the_super = [item[0] for item in those_the]

# %%
the = 'GEO_ID'
name = 'NAME' 

those.append(the)

# %%
those_the_super
# Out:
# ['DP02_0001E',
#  'DP02_0002E',
#  'DP02_0002PE',
#  'DP02_0004PE',
#  'DP02_0017E',
#  'DP02_0024E',
#  'DP02_0025PE',
#  'DP02_0026PE',
#  'DP02_0027PE',
#  'DP02_0029PE',
#  'DP02_0030E',
#  'DP02_0031PE',
#  'DP02_0032PE',
#  'DP02_0033PE',
#  'DP02_0035PE',
#  'DP02_0036E',
#  'DP02_0036M',
#  'DP02_0037PE',
#  'DP02_0039E',
#  'DP02_0040E',
#  'DP02_0041E',
#  'DP02_0042E',
#  'DP02_0052E',
#  'DP02_0052PE',
#  'DP02_0053PE',
#  'DP02_0054PE',
#  'DP02_0055PE',
#  'DP02_0056PE',
#  'DP02_0057PE',
#  'DP02_0058E',
#  'DP02_0059PE',
#  'DP02_0060PE',
#  'DP02_0061PE',
#  'DP02_0062PE',
#  'DP02_0063PE',
#  'DP02_0064PE',
#  'DP02_0065PE',
#  'DP02_0066PE',
#  'DP02_0067PE',
#  'DP02_0069E',
#  'DP02_0069PE',
#  'DP02_0071E',
#  'DP02_0071PE',
#  'DP02_0078E',
#  'DP02_0078PE',
#  'DP02_0084E',
#  'DP02_0084PE',
#  'DP02_0085E',
#  'DP02_0085PE',
#  'DP02_0087PE',
#  'DP02_0088PE',
#  'DP02_0089PE',
#  'DP02_0090PE',
#  'DP02_0092PE',
#  'DP02_0111PE',
#  'DP02_0112PE',
# ...

# %%
len(these)
# Out:
# 381

# %%
all_tables[those_the_super]
# Out:
#                                            DP02_0001E  \
# 0      Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1                                                  88
# 2                                                 993
# 3                                                1472
# 4                                                 308
# ...                                               ...
# 58364                                             NaN
# 58365                                             NaN
# 58366                                             NaN
# 58367                                             NaN
# 58368                                             NaN
#
#                                               DP02_0002E  \
# 0      Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 1                                                     26
# 2                                                    614
# 3                                                   1061
# ...

# %%
#good_stuff2 = all_states2[these2]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-35cba198b8dd> in <module>
# ----> 1 good_stuff = all_states2[these2]
#
# ~\Miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2785         # Do we have a (boolean) DataFrame?
#    2786         if isinstance(key, DataFrame):
# -> 2787             return self.where(key)
#    2788
#    2789         # Do we have a (boolean) 1d indexer?
#
# ~\Miniconda3\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8919         other = com.apply_if_callable(other, self)
#    8920         return self._where(
# -> 8921             cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#    8922         )
#    8923
#
# ...

# %%
good_stuff2

# %%
crime = pd.read_csv('./data/crime.csv', low_memory=False)
crime
# Out:
#                      city  vcr_2018  pcr_2018  vcr_2017  pcr_2017  vcr_2016  pcr_2016  vcr_2015  pcr_2015  vcr_2014  pcr_2014  vcr_2013  pcr_2013  vcr_2012  pcr_2012  vcr_2011  pcr_2011  vcr_2010  pcr_2010  vcr_2009  pcr_2009
