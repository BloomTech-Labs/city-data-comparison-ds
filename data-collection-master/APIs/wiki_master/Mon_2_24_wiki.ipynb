# %%
pip install wikipedia
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wikipedia

# %%
print(wikipedia.page(47.656806, -117.424347))
#47.656806, -117.424347
# Out:
# <WikipediaPage 'The Davenport Hotel (Spokane, Washington)'>

# %%
import pandas as pd

# %%
num = pd.read_csv('table1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-9836b1653aba> in <module>
# ----> 1 num = pd.read_csv('table1.csv')
#
# ~\Miniconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
num4 = pd.read_csv(r'C:\Users\zebfr\city-data1\retry_3000_forreal\city-data-comparison-ds\Ori_work\table1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-5a3488942422> in <module>
# ----> 1 num4 = pd.read_csv(r'C:\Users\zebfr\city-data1\retry_3000_forreal\city-data-comparison-ds\Ori_work\table1.csv')
#
# ~\Miniconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
num4
# Out:
#                GEO_ID                        NAME  \
# 0                  id        Geographic Area Name
# 1    1600000US0100100         Abanda CDP, Alabama
# 2    1600000US0100124     Abbeville city, Alabama
# 3    1600000US0100460    Adamsville city, Alabama
# 4    1600000US0100484       Addison town, Alabama
# ..                ...                         ...
# 581  1600000US0183400      Woodland town, Alabama
# 582  1600000US0183640     Woodstock town, Alabama
# 583  1600000US0183664     Woodville town, Alabama
# 584  1600000US0183976  Yellow Bluff town, Alabama
# 585  1600000US0184096          York city, Alabama
#
#                         S0101_C01_001E  \
# 0    Estimate!!Total!!Total population
# 1                                  218
# 2                                 2582
# 3                                 4374
# 4                                  641
# ..                                 ...
# 581                                204
# ...

# %%
df_num5 = pd.read_csv('./zipcode_table.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-f1f842bc6d90> in <module>
# ----> 1 df_num5 = pd.read_csv('./zipcode_table.csv')
#
# ~\Miniconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...
