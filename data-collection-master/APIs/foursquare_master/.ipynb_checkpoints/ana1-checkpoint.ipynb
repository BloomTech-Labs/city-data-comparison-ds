# %%
import json

w#ith open('venues/ids.json', 'r') as fp:
 #   bycity = json.load(fp)

#print(bycity)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import json

# %%
import json
import pandas as pd
with open('venues/city_ids.json', 'r') as f:
    data = json.load(f)
df = pd.DataFrame(data)

# %%
df_T = df.T
df_T2 = df_T.reset_index()
df_Tf = df_T2.rename(columns = {'index':'city'})
df_Tf
# Out:
#                    city     ID  st     state      lat      lng population
# 0      Russellville, AL      0  AL   Alabama  34.5056 -87.7282       9711
# 1              Vina, AL      1  AL   Alabama  34.3757 -88.0602        363
# 2        Providence, AL      2  AL   Alabama  32.3424 -87.7761        179
# 3             Grant, AL      3  AL   Alabama  34.5189 -86.2492        933
# 4          Daviston, AL      4  AL   Alabama  33.0557 -85.6371        186
# ...                 ...    ...  ..       ...      ...      ...        ...
# 28920  Anchorage AK, AL  28920  AL    Alaska  61.2181   -149.9     296112
# 28921        Athens, GA  28921  GA   Georgia  33.9519 -83.3576     123310
# 28922       Augusta, GA  28922  GA   Georgia  33.4735 -82.0105     196807
# 28923     Lexington, KY  28923  KY  Kentucky  38.0406 -84.5037     318734
# 28924    Louisville, KY  28924  KY  Kentucky  38.2527 -85.7585     617032
#
# [28925 rows x 7 columns]

# %%
# Select first building (which in our case is BedokVille):
neighborhood_name = df_Tf.loc[0, 'city']
neighborhood_latitude = df_Tf.loc[0, 'lat'] 
neighborhood_longitude = df_Tf.loc[0, 'lng'] 
# limit of number of venues returned by Foursquare API
LIMIT = 100 
radius = 500

# %%
CLIENT_ID = ‘your-client-ID’ # your Foursquare ID
CLIENT_SECRET = ‘your-client-secret’ # your Foursquare Secret
VERSION = ‘20180604’
LIMIT = 100

# %%
#import foursquare, time


client_id='Y1CPCQJRBWVHOPPLP1IHFWVYRSIGKNDY4PN32X1OWCSAVVPN',
client_secret='1CEWCHG0YU00VP1JZ4P0T0VRNOX43FB2IIUE3G1F511TEGRX'
VERSION =  '20180323'
LIMIT = 100

# %%
import json, requests
url = 'https://api.foursquare.com/v2/venues/explore'

params = dict(
  client_id='Y1CPCQJRBWVHOPPLP1IHFWVYRSIGKNDY4PN32X1OWCSAVVPN',
  client_secret='1CEWCHG0YU00VP1JZ4P0T0VRNOX43FB2IIUE3G1F511TEGRX',
  v='20180323',
  ll='40.7243,-74.0018',
  query='coffee',
  limit=1
)
resp = requests.get(url=url, params=params)
data = json.loads(resp.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '5e5efa22df2774001b4578f8'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'warning': {'text': 'There aren\'t a lot of results for "coffee." Try something more general, reset your filters, or expand the search area.'},
#   'suggestedRadius': 600,
#   'headerLocation': 'SoHo',
#   'headerFullLocation': 'SoHo, New York',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'coffee',
#   'totalResults': 79,
#   'suggestedBounds': {'ne': {'lat': 40.727318083147175,
#     'lng': -74.00258497963885},
#    'sw': {'lat': 40.724618423361726, 'lng': -73.99986745215081}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
# ...

# %%
client_ID='Y1CPCQJRBWVHOPPLP1IHFWVYRSIGKNDY4PN32X1OWCSAVVPN'
client_SECRET='1CEWCHG0YU00VP1JZ4P0T0VRNOX43FB2IIUE3G1F511TEGRX'

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    client_ID, 
    client_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
results = requests.get(url).json()

# %%
# !pip install folium

# %%
# !pip install geopy

# %%
from pandas.io.json import json_normalize
import folium
from geopy.geocoders import Nominatim 
import requests

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = pd.json_normalize(venues)

# %%
print(nearby_venues)
# Out:
#                        referralId  reasons.count  \
# 0  e-0-5626a0f5498e98c07b190f44-0              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id                        venue.name  \
# 0  5626a0f5498e98c07b190f44  Atkins Marble  Granite Works Inc
#
#   venue.location.address  venue.location.lat  venue.location.lng  \
# 0      403 Lawrence St E           34.501694           -87.72553
#
#                        venue.location.labeledLatLngs  venue.location.distance  \
# 0  [{'label': 'display', 'lat': 34.5016938091772,...                      499
#
#    ... venue.stats.visitsCount venue.beenHere.count  \
# 0  ...                       0                    0
#
#   venue.beenHere.lastCheckinExpiredAt venue.beenHere.marked  \
# 0                                   0                 False
#
#   venue.beenHere.unconfirmedCount venue.photos.count venue.photos.groups  \
# ...

# %%
print(venues)
# Out:
# [{'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '5626a0f5498e98c07b190f44', 'name': 'Atkins Marble  Granite Works Inc', 'contact': {}, 'location': {'address': '403 Lawrence St E', 'lat': 34.5016938091772, 'lng': -87.72552967071533, 'labeledLatLngs': [{'label': 'display', 'lat': 34.5016938091772, 'lng': -87.72552967071533}], 'distance': 499, 'postalCode': '35653', 'cc': 'US', 'city': 'Russellville', 'state': 'AL', 'country': 'United States', 'formattedAddress': ['403 Lawrence St E', 'Russellville, AL 35653', 'United States']}, 'categories': [{'id': '5453de49498eade8af355881', 'name': 'Business Service', 'pluralName': 'Business Services', 'shortName': 'Business Services', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 0, 'usersCount': 0, 'checkinsCount': 0, 'visitsCount': 0},
# ...

# %%
from pandas.io.json import json_normalize
import folium
from geopy.geocoders import Nominatim 
import requests

# %%
#!pip install foursquare

# %%
import foursquare, time

client = foursquare.Foursquare(
    client_id='Y1CPCQJRBWVHOPPLP1IHFWVYRSIGKNDY4PN32X1OWCSAVVPN',
    client_secret='1CEWCHG0YU00VP1JZ4P0T0VRNOX43FB2IIUE3G1F511TEGRX'
)

def venues_by_cityname(cityname):
    params = dict(near=cityname)
    try:
        data = client.venues.search(params=params)
        return sorted([v['id'] for v in data['venues']])
    except foursquare.FailedGeocode:
        return None
    except foursquare.ServerError:
        time.sleep(60)
        return venues_by_cityname(cityname)

# %%
print(venues_by_cityname('New York'))
# Out:
# ['4a21834ff964a520077d1fe3', '4a881c9cf964a520310520e3', '4ac23730f964a5203a9820e3', '4b696ecdf964a5201fa22be3', '4be6ceb9bcef2d7fbd7405e5', '4c5ef77bfff99c74eda954d3', '4d8ea211d265236a30bd0f17', '509ee5bbe4b0f56d613db4a9', '534e9a2211d247e3854371f2', '5495e8ad498e505982f59030', '54e671c3498eac6116ab33da', '554ca083498efd419209c432', '573363c2498eb18e283007f8', '576bd714498e6b2020b3afb9', '591620d82aff31013a58214d', '5a0f9ae9bb2a474024a14c13', '5a187743ccad6b307315e6fe', '5a21c39660255e3bca85e261', '5a22dddc66611634a1845844', '5aaa8ad153159351e02cdd56', '5ab1f0cf0a08ab0f4ac7fbd3', '5ae86b42fe3740002ca5c615', '5b55e952c4404e001c4c18a8', '5bcf50fedeb4950025b9cad5', '5bf34fca018cbb002c99be4a', '5c02ee890868a200399c1614', '5c5af75d464d65002cfb95b1', '5c7afef10719020025ef6105', '5d4c6e7a3d4ea60008af0ebc', '5d5afcf2011df00008f79a94']

# %%
help(foursquare)
# Out:
# Help on package foursquare:
#
# NAME
#     foursquare
#
# DESCRIPTION
#     # -*- coding: UTF-8 -*-
#     # (c) 2020 Mike Lewis
#
# PACKAGE CONTENTS
#     tests (package)
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         FoursquareException
#             Deprecated
#             EndpointError
#             FailedGeocode
#             GeocodeTooBig
#             InvalidAuth
#             NotAuthorized
#             Other
#             ParamError
#             RateLimitExceeded
#             ServerError
#     builtins.object
#         Foursquare
#
#     class Deprecated(FoursquareException)
#      |  Common base class for all non-exit exceptions.
#      |
#      |  Method resolution order:
#      |      Deprecated
#      |      FoursquareException
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors inherited from FoursquareException:
#      |
#      |  __weakref__
# ...
