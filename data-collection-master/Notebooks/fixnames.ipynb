# %%
import pandas as pd

# %%
df = pd.read_csv('data/notop2.csv')
# Out:
# C:\Users\WIN 10\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (12,16,20,24,28,32,36,40,44,48,52,56,60,62,66,70,76,80,84,88,92,96,104,108,112,116,120,128,132,136,140,144,154,158,166,170,216,220,224,228,232,234,240,244,248,252,256,260,264,268,272,280,288,296,304,312,320,324,328,332,336,340,344,346,352,356,360,364,368,372,442,448,452,456,460,464,468,472,476,480,484,488,490,496,500,504,508,512,516,520,524,528,532,536,540,544,548,552,556,560,564,568,572,576,580,584,588,592,596,600,608,612,622,626,630,634,638,642,650,658,662,666,682,690,694,698,702,706,710,711,712,713,714,722,726,730,734,738,746,750,754,758,762,766,770,774,778,782,786,790,794,802,806,810,814,822,826,830,834,838,842,846,850,854,858,859,860,863,864,865,866,870,871,872,873,874,878,879,880,881,882,886,887,888,889,890,894,902,910,918,922,926,930,934,938,942,946,950,954,955,959,960,961,962,963,964,965,966,971,975,976,977,978,979,983,987,998,1002,1006,1010,1018,1034,1038,1042,1046,1074,1
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 0           0             1               1  1600000US0167056
# 1           1             2               2  1600000US0178984
# 2           2             3               3  1600000US0162688
# 3           3             4               4  1600000US0131096
# 4           4             5               5  1600000US0119816
#
#                          NAME  DP02_0001E  DP02_0001M  DP02_0001PE  \
# 0  Russellville city, Alabama        3208         282         3208
# 1          Vina town, Alabama         146          37          146
# 2    Providence town, Alabama         101          29          101
# 3         Grant town, Alabama         367          58          367
# 4      Daviston town, Alabama          93          29           93
#
#    DP02_0001PM  DP02_0002E  ...  DP05_0087PE  DP05_0087PM DP05_0088E  \
# 0          NaN        2195  ...         5370          NaN       2750
# ...

# %%
df.shape
# Out:
# (29314, 2095)

# %% [markdown]
# ### Get ride of outliers

# %%
df = df[df.state != 'Village of Islands village; Florida']
df = df[df.state != 'Moore County metropolitan government; Tennessee']

# %%
def state(st):
    return(st.split(',')[-1].strip())

df['state'] = df.NAME.apply(state)
df.state.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df.state.nunique()
# Out:
# 51

# %% [markdown]
# ## This following section takes a look at the type of region (city, town, borough, village)

# %%
def marker(mk):
    return(mk.split(',')[0].strip().split()[-1])

df['marker'] = df.NAME.apply(marker)
df.marker.unique()
# Out:
# array(['city', 'town', 'CDP', 'County)', 'borough', 'municipality',
#        '(balance)', 'village', 'County', 'government', 'county',
#        'Counties)', 'City', 'Princeton', 'corporation'], dtype=object)

# %%
df.marker.nunique()
# Out:
# 15

# %%
df[df.marker == 'borough']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 629           629           630             630  1600000US0236400
# 662           662           663             663  1600000US0270540
# 921           921           922             922  1600000US0286380
# 3935         3935          3936            3936  1600000US0927810
# 3940         3940          3941            3941  1600000US0988050
# 3944         3944          3945            3945  1600000US0943300
# 3946         3946          3947            3947  1600000US0934460
# 3954         3954          3955            3955  1600000US0952910
# 3976         3976          3977            3977  1600000US0973700
# 4006         4006          4007            4007  1600000US0949880
# 4026         4026          4027            4027  1600000US0939940
# 4029         4029          4030            4030  1600000US0918780
# 4034         4034          4035            4035  1600000US0902690
# ...

# %%
df[df.marker == 'County)']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 513           513           514             514  1600000US0152344
# 568           568           569             569  1600000US0152320
# 1332         1332          1333            1333  1600000US0459760
# 1336         1336          1337            1337  1600000US0459690
# 2431         2431          2432            2432  1600000US0604470
# 2577         2577          2578            2578  1600000US0668263
# 2596         2596          2597            2597  1600000US0673696
# 2645         2645          2646            2646  1600000US0614450
# 2759         2759          2760            2760  1600000US0673690
# 2789         2789          2790            2790  1600000US0631092
# 2847         2847          2848            2848  1600000US0625488
# 2860         2860          2861            2861  1600000US0604478
# 2866         2866          2867            2867  1600000US0631099
# ...

# %%
df[df.marker == '(balance)']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 4037         4037          4038            4038  1600000US0947515
# 5134         5134          5135            5135  1600000US1304204
# 5136         5136          5137            5137  1600000US1303440
# 7457         7457          7458            7458  1600000US1836003
# 9110         9110          9111            9111  1600000US2028412
# 10230       10230         10231           10231  1600000US2148006
# 14837       14837         14838           14838  1600000US3011397
# 24142       24142         24143           24143  1600000US4752006
#
#                                                     NAME  DP02_0001E  \
# 4037                 Milford city (balance), Connecticut       20938
# 5134   Augusta-Richmond County consolidated governmen...       70659
# 5136   Athens-Clarke County unified government (balan...       45763
# 7457                Indianapolis city (balance), Indiana      333316
# ...

# %%
df[]

# %%
#drop county

df[df.marker == 'County']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 5058         5058          5059            5059  1600000US1349008
# 14791       14791         14792           14792  1600000US3001675
# 24143       24143         24144           24144  1600000US4732742
#
#                                          NAME  DP02_0001E  DP02_0001M  \
# 5058               Macon-Bibb County, Georgia       57200         845
# 14791     Anaconda-Deer Lodge County, Montana        3984         305
# 24143  Hartsville/Trousdale County, Tennessee        2944         167
#
#        DP02_0001PE  DP02_0001PM  DP02_0002E  ...  DP05_0088E  DP05_0088M  \
# 5058         57200          NaN       34528  ...       51396         249
# 14791         3984          NaN        2317  ...        4059         107
# 24143         2944          NaN        1904  ...        3566          64
#
#       DP05_0088PE  DP05_0088PM  DP05_0089E  DP05_0089M DP05_0089PE  \
# ...

# %%
#Drop government
df[df.marker == 'government']
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 5139        5139          5140            5140  1600000US1332528
# 5140        5140          5141            5141  1600000US1321017
# 5141        5141          5142            5142  1600000US1381128
# 5167        5167          5168            5168  1600000US1326156
#
#                                                    NAME  DP02_0001E  \
# 5139  Georgetown-Quitman County unified government, ...         978
# 5140  Cusseta-Chattahoochee County unified governmen...        2505
# 5141         Webster County unified government, Georgia        1091
# 5167     Echols County consolidated government, Georgia        1502
#
#       DP02_0001M  DP02_0001PE  DP02_0001PM  DP02_0002E  ...  DP05_0088E  \
# 5139         118          978          NaN         571  ...         850
# 5140         227         2505          NaN        1832  ...        6026
# 5141          94         1091          NaN         735  ...         999
# ...

# %%
#drop county
df[df.marker == 'county']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 10229       10229         10230           10230  1600000US2146027
#
#                                            NAME  DP02_0001E  DP02_0001M  \
# 10229  Lexington-Fayette urban county, Kentucky      127336         942
#
#        DP02_0001PE  DP02_0001PM  DP02_0002E  ...  DP05_0088E  DP05_0088M  \
# 10229       127336          NaN       73105  ...      110798         703
#
#       DP05_0088PE  DP05_0088PM  DP05_0089E  DP05_0089M DP05_0089PE  \
# 10229        48.0          0.1      119853         479        52.0
#
#        DP05_0089PM     state  marker
# 10229          0.1  Kentucky  county
#
# [1 rows x 2097 columns]

# %%
df[df.marker == 'Counties)']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 12890       12890         12891           12891  1600000US2756680
# 13616       13616         13617           13617  1600000US2807330
# 25451       25451         25452           25452  1600000US4861604
#
#                                                     NAME  DP02_0001E  \
# 12890  St. Anthony city (Hennepin and Ramsey Counties...        3859
# 13616  Bogue Chitto CDP (Kemper and Neshoba Counties)...         298
# 25451     Reno city (Parker and Tarrant Counties), Texas         906
#
#        DP02_0001M  DP02_0001PE  DP02_0001PM  DP02_0002E  ...  DP05_0088E  \
# 12890         157         3859          NaN        2192  ...        2898
# 13616          93          298          NaN         177  ...         274
# 25451         106          906          NaN         677  ...         977
#
#        DP05_0088M DP05_0088PE  DP05_0088PM  DP05_0089E  DP05_0089M  \
# ...

# %%
df[df.marker == 'City']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 15663       15663         15664           15664  1600000US3209700
#
#                       NAME  DP02_0001E  DP02_0001M  DP02_0001PE  DP02_0001PM  \
# 15663  Carson City, Nevada       22158         337        22158          NaN
#
#        DP02_0002E  ...  DP05_0088E  DP05_0088M DP05_0088PE  DP05_0088PM  \
# 15663       13336  ...       20297         399        51.2          0.6
#
#        DP05_0089E  DP05_0089M DP05_0089PE  DP05_0089PM   state  marker
# 15663       19353         232        48.8          0.6  Nevada    City
#
# [1 rows x 2097 columns]

# %%
df[df.marker == 'Princeton']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 16318       16318         16319           16319  1600000US3460900
#
#                         NAME  DP02_0001E  DP02_0001M  DP02_0001PE  \
# 16318  Princeton, New Jersey        9997         431         9997
#
#        DP02_0001PM  DP02_0002E  ...  DP05_0088E  DP05_0088M DP05_0088PE  \
# 16318          NaN        6625  ...       10440         512        49.3
#
#        DP05_0088PM  DP05_0089E  DP05_0089M DP05_0089PE  DP05_0089PM  \
# 16318          1.6       10724         502        50.7          1.6
#
#             state     marker
# 16318  New Jersey  Princeton
#
# [1 rows x 2097 columns]

# %%
df[df.marker == 'corporation']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 28250       28250         28251           28251  1600000US5466988
#
#                                     NAME  DP02_0001E  DP02_0001M  DP02_0001PE  \
# 28250  Ranson corporation, West Virginia        1859         116         1859
#
#        DP02_0001PM  DP02_0002E  ...  DP05_0088E  DP05_0088M DP05_0088PE  \
# 28250          NaN        1263  ...        1630         184        47.7
#
#        DP05_0088PM  DP05_0089E  DP05_0089M DP05_0089PE  DP05_0089PM  \
# 28250          3.8        1790         158        52.3          3.8
#
#                state       marker
# 28250  West Virginia  corporation
#
# [1 rows x 2097 columns]

# %% [markdown]
# ## Dataset to help abbreviate each state

# %%
copy = pd.read_html('https://www.infoplease.com/us/postal-information/state-abbreviations-and-state-postal-codes')
codes = copy[0]
zipped = dict(zip(codes['State/District'].values, codes['Postal Code'].values))
codes.head()
# Out:
#   State/District Abbreviation Postal Code
# 0        Alabama         Ala.          AL
# 1         Alaska       Alaska          AK
# 2        Arizona        Ariz.          AZ
# 3       Arkansas         Ark.          AR
# 4     California       Calif.          CA

# %%
import numpy as np
def abb(st):
    return(zipped[st])

df['st'] = df.state.apply(abb)
df['full_name'] = np.NaN * len(df)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 0           0             1               1  1600000US0167056
# 1           1             2               2  1600000US0178984
# 2           2             3               3  1600000US0162688
# 3           3             4               4  1600000US0131096
# 4           4             5               5  1600000US0119816
#
#                          NAME  DP02_0001E  DP02_0001M  DP02_0001PE  \
# 0  Russellville city, Alabama        3208         282         3208
# 1          Vina town, Alabama         146          37          146
# 2    Providence town, Alabama         101          29          101
# 3         Grant town, Alabama         367          58          367
# 4      Daviston town, Alabama          93          29           93
#
#    DP02_0001PM  DP02_0002E  ...  DP05_0088PE  DP05_0088PM DP05_0089E  \
# 0          NaN        2195  ...         51.2          4.3       2620
# ...

# %%
df.values[0][-2]
# Out:
# 'AL'

# %% [markdown]
# ## Create a new dataset with formated city, town, village, and borough locations

# %%
new = []
for i in df.values:
    check = i[4].split(',')[0]
    if ' city' in check:
        i[-1] = check.split(' city')[0].strip()
        i[-1] = f"{i[-1]} {i[-2]}"
        new.append(i)
    elif ' town' in check:
        i[-1] = check.split(' town')[0].strip()  
        i[-1] = f"{i[-1]} {i[-2]}"
        new.append(i)
    elif ' village' in check:
        i[-1] = check.split(' village')[0].strip() 
        i[-1] = f"{i[-1]} {i[-2]}"
        new.append(i)        
    elif ' borough' in check:
        i[-1] = check.split(' borough')[0].strip() 
        i[-1] = f"{i[-1]} {i[-2]}"
        new.append(i)
    elif check == 'Carson City':
        i[-1] = 'Carson City'  
        i[-1] = f"{i[-1]} {i[-2]}"
        new.append(i)
    elif check == 'Princeton':
        i[-1] = 'Princeton' 
        i[-1] = f"{i[-1]} {i[-2]}"
        new.append(i) 
    elif 'Nashville-Davidson metropolitan' in check:
        i[-1] = 'Nashville' 
        i[-1] = f"{i[-1]} {i[-2]}"
        new.append(i) 
    else:
        pass

# %%
len(new)
# Out:
# 19510

# %%
cites = pd.DataFrame(new, columns=df.columns)

# %%
cites.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 0           0             1               1  1600000US0167056
# 1           1             2               2  1600000US0178984
# 2           2             3               3  1600000US0162688
# 3           3             4               4  1600000US0131096
# 4           4             5               5  1600000US0119816
#
#                          NAME  DP02_0001E  DP02_0001M  DP02_0001PE  \
# 0  Russellville city, Alabama        3208         282         3208
# 1          Vina town, Alabama         146          37          146
# 2    Providence town, Alabama         101          29          101
# 3         Grant town, Alabama         367          58          367
# 4      Daviston town, Alabama          93          29           93
#
#    DP02_0001PM  DP02_0002E  ...  DP05_0088PE  DP05_0088PM DP05_0089E  \
# 0          NaN        2195  ...         51.2          4.3       2620
# ...

# %% [markdown]
# ## Dataset for CDP locations

# %%
cdp = []
for i in df.values:
    check = i[4].split(',')[0]
    if ' CDP' in check:
        i[-1] = check.split(' CDP')[0].strip()
        i[-1] = f"{i[-1]} {i[-2]}"
        cdp.append(i)
    else:
        pass

# %%
new2 = new.copy()

# %%
check_name = cites['full_name'].values

# %%
for i in cdp:
    if i[-1] not in check_name:
        new2.append(i)
        
    else:
        pass

# %%
len(cdp)
# Out:
# 9784

# %%
len(new)
# Out:
# 19510

# %%
len(new2)
# Out:
# 29198

# %%
allcity = pd.DataFrame(new2, columns=df.columns)

# %%
allcity.shape
# Out:
# (29198, 2099)

# %%
allcity.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 0           0             1               1  1600000US0167056
# 1           1             2               2  1600000US0178984
# 2           2             3               3  1600000US0162688
# 3           3             4               4  1600000US0131096
# 4           4             5               5  1600000US0119816
#
#                          NAME  DP02_0001E  DP02_0001M  DP02_0001PE  \
# 0  Russellville city, Alabama        3208         282         3208
# 1          Vina town, Alabama         146          37          146
# 2    Providence town, Alabama         101          29          101
# 3         Grant town, Alabama         367          58          367
# 4      Daviston town, Alabama          93          29           93
#
#    DP02_0001PM  DP02_0002E  ...  DP05_0088PE  DP05_0088PM DP05_0089E  \
# 0          NaN        2195  ...         51.2          4.3       2620
# ...

# %%
cdp[0]
# Out:
# array([7, 8, 8, ..., 'CDP', 'AL', 'Moores Mill AL'], dtype=object)

# %%
9784 + 19706
# Out:
# 29490

# %% [markdown]
# ## Cross checking the major cities are in the dataset

# %%
pop_checkdf = pd.read_csv('data/popcheck.csv')

# %%
pop_checkdf.head()
# Out:
#    Unnamed: 0    City Name  State Name  Population  \
# 0           0     New York    New York     8622698
# 1           1  Los Angeles  California     3999759
# 2           2      Chicago    Illinois     2716450
# 3           3      Houston       Texas     2312717
# 4           4      Phoenix     Arizona     1626078
#
#   Population Growth 2000-2017  st            city
# 0                       7.50%  NY     New York NY
# 1                       7.90%  CA  Los Angeles CA
# 2                      -6.10%  IL      Chicago IL
# 3                      16.90%  TX      Houston TX
# 4                      22.50%  AZ      Phoenix AZ

# %%
#pop_checkdf.to_csv('data/popcheck.csv')

# %%
pop_checkdf['st'] = pop_checkdf['State Name'].apply(abb)
pop_checkdf.head()
# Out:
#    Unnamed: 0    City Name  State Name  Population  \
# 0           0     New York    New York     8622698
# 1           1  Los Angeles  California     3999759
# 2           2      Chicago    Illinois     2716450
# 3           3      Houston       Texas     2312717
# 4           4      Phoenix     Arizona     1626078
#
#   Population Growth 2000-2017  st            city
# 0                       7.50%  NY     New York NY
# 1                       7.90%  CA  Los Angeles CA
# 2                      -6.10%  IL      Chicago IL
# 3                      16.90%  TX      Houston TX
# 4                      22.50%  AZ      Phoenix AZ

# %%
ins = [f"{i[0]} {i[1]}" for i in pop_checkdf[['City Name', 'st']].values]

# %%
pop_checkdf['city'] = ins

# %%
pop_checkdf.to_csv('data/popcheck.csv')

# %%
check_name = cites['full_name'].values
check_all = allcity['full_name'].values

# %%
for i in pop_checkdf.city.values:
    if i not in check_name:
        print(i)
# Out:
# Nashville-Davidson TN
# Louisville/Jefferson County KY
# Honolulu HI
# Lexington-Fayette KY
# Anchorage AK
# Augusta-Richmond County GA
# Macon-Bibb County GA
# Athens-Clarke County GA
# Millcreek UT
# Stonecrest GA
# Methuen MA

# %%
for i in pop_checkdf.city.values:
    if i not in check_all:
        print(i)
# Out:
# Nashville-Davidson TN
# Louisville/Jefferson County KY
# Honolulu HI
# Lexington-Fayette KY
# Anchorage AK
# Augusta-Richmond County GA
# Macon-Bibb County GA
# Athens-Clarke County GA
# Stonecrest GA
# Methuen MA

# %%
city5000 = pd.read_clipboard()

# %%
city5000['pop'] = city5000['pop'].apply(com)

# %%
cit = [f"{i[0].strip()} {i[1].strip()}" for i in city5000[['city', 'st']].values]
city5000['full_name'] = cit

# %% [markdown]
# ## checking which of the top 5000 cities are missing

# %%
city5000 = pd.read_csv('data/top5000.csv')
city5000.head()
# Out:
#    Unnamed: 0          city  st      pop       full_name
# 0           0     New York   NY  8363710     New York NY
# 1           1  Los Angeles   CA  3833995  Los Angeles CA
# 2           2      Chicago   IL  2853114      Chicago IL
# 3           3      Houston   TX  2242193      Houston TX
# 4           4      Phoenix   AZ  1567924      Phoenix AZ

# %%
a = 0
for i in city5000.full_name.values:
    if i not in check_all:
        a += 1
        print(str(a) + '  ' + i)
# Out:
# 1  Louisville KY
# 2  Honolulu HI
# 3  Lexington KY
# 4  Anchorage AK
# 5  Augusta GA
# 6  Athens GA
# 7  Ventura CA
# 8  Macon GA
# 9  Methuen MA
# 10  Watertown MA
# 11  Franklin MA
# 12  Butte-Silver Bow MT
# 13  Bethel Park PA
# 14  Paso Robles CA
# 15  Agawam MA
# 16  Monroeville PA
# 17  West Springfield MA
# 18  De Land FL
# 19  La Cada Flintridge CA
# 20  Murrysville PA
# 21  Easthampton MA
# 22  Can City CO
# 23  Cusseta GA
# 24  West Carrollton City OH
# 25  West Paterson NJ
# 26  Espanola NM
# 27  Sitka  and AK
# 28  Anaconda MT
# 29  Hartsville TN
# 30  Islamorada, Village of Islands FL
# 31  Lynchburg TN
# 32  De Funiak Springs FL
# 33  Ranson corporation WV
# 34  Waverly City OH
# 35  McRae GA

# %%
cites.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 0           0             1               1  1600000US0167056
# 1           1             2               2  1600000US0178984
# 2           2             3               3  1600000US0162688
# 3           3             4               4  1600000US0131096
# 4           4             5               5  1600000US0119816
#
#                          NAME  DP02_0001E  DP02_0001M  DP02_0001PE  \
# 0  Russellville city, Alabama        3208         282         3208
# 1          Vina town, Alabama         146          37          146
# 2    Providence town, Alabama         101          29          101
# 3         Grant town, Alabama         367          58          367
# 4      Daviston town, Alabama          93          29           93
#
#    DP02_0001PM  DP02_0002E  ...  DP05_0088PE  DP05_0088PM DP05_0089E  \
# 0          NaN        2195  ...         51.2          4.3       2620
# ...

# %%
dubs = pd.DataFrame(allcity.groupby('full_name')['full_name'].count().sort_values(ascending=False))
dubs = dubs.rename(columns={'full_name':'count'})
dubs.head()
# Out:
#                 count
# full_name
# Chula Vista TX      3
# Oakwood OH          3
# Aaronsburg PA       2
# Oak Ridge TX        2
# Bayview CA          2

# %% [markdown]
# ## Taking care of doubles

# %%
dubs = dubs.reset_index()

# %%
dubsnames = dubs[dubs['count'] > 1].full_name.values

# %%
def ddubs(cit):
    if cit in nodubs.NAME.values:
        print()
    return(nodubs[nodubs['NAME'] != cit])

def cdub(st):
    return(allcitpop[allcitpop['full_name'] == st])

def fin(st):
    return(nodubs[nodubs['full_name'] == st])

# %%
for i in dubs[['full_name', 'count']].values:
    print(f'{i[1]}   {i[0]}')
# Out:
# 3   Chula Vista TX
# 3   Oakwood OH
# 2   Aaronsburg PA
# 2   Oak Ridge TX
# 2   Bayview CA
# 2   Franklin CA
# 2   San Antonito NM
# 2   Woodlawn MD
# 2   Wilmington IL
# 2   Lakeside TX
# 2   Newburg PA
# 2   Walnut Grove TN
# 2   Clear Lake WA
# 2   Kailua HI
# 2   St. Anthony MN
# 2   Loma Linda East TX
# 2   Oak Grove TN
# 2   Bogue Chitto MS
# 2   Centerville PA
# 2   Shady Grove OK
# 2   Strawberry CA
# 2   Green Valley CA
# 2   Woodlawn VA
# 2   Mount Olive AL
# 2   University FL
# 2   Whitfield FL
# 2   Pleasantville PA
# 2   Sunset TX
# 2   Pewaukee WI
# 2   Windsor IL
# 2   Waimea HI
# 2   Superior WI
# 2   Greenville NY
# 2   Jefferson PA
# 2   Liberty PA
# 2   Hilltop TX
# 2   Milton NY
# 2   Fredericksburg PA
# 2   Torreon NM
# 2   Centerville OH
# 2   El Sobrante CA
# 2   Twin Lakes CO
# 2   San Miguel CA
# 2   Fairview NY
# 2   Las Flores CA
# 2   Jacksonville PA
# 2   Pine Ridge FL
# 2   Silver Lake NJ
# 2   San Jose NM
# 2   Rose Hill VA
# 2   Eagleville PA
# ...

# %%
nodubs = allcity.copy()

# %%
allcitpop = allcity[['NAME', 'full_name', 'DP05_0001E']]

# %%
a = 'Chula Vista TX'
cdub(a)
# Out:
#                                            NAME       full_name  DP05_0001E
# 27485    Chula Vista CDP (Zavala County), Texas  Chula Vista TX         899
# 27765  Chula Vista CDP (Maverick County), Texas  Chula Vista TX        4042
# 27834   Chula Vista CDP (Cameron County), Texas  Chula Vista TX         486

# %%
d = cdub(a)

# %%
for i in dubsnames:
    d = allcitpop[allcitpop['full_name'] == i]
    for row in d.sort_values('DP05_0001E', ascending=False).NAME.values[1:].tolist():
        nodubs = nodubs[nodubs['NAME'] != row]

# %%
dubs2 = pd.DataFrame(nodubs.groupby('full_name')['full_name'].count().sort_values(ascending=False))

# %%
allcitpop.shape
# Out:
# (29198, 3)

# %%
nodubs.shape
# Out:
# (29132, 2099)

# %% [markdown]
# ## Cleaning the missing outliers

# %%
def find_missing(st):
    for i in nodubs.values:
        if st in i[4]:
            print(f"{i[1739]}   {i[4]}  {i[-1]}")
            print(' ')
def dropit(name):
    return(nodubs[nodubs['NAME'] != name])

def fixname(name, newname):
    num = nodubs[nodubs.full_name == name].index[0]
    nodubs.loc[num, 'full_name'] = newname

# %%
check_all = nodubs.full_name.values

# %%
def

# %%
a = 0
for i in city5000.full_name.values:
    if i not in check_all:
        a += 1
        print(str(a) + '  ' + i)
# Out:
# 1  Louisville KY
# 2  Lexington KY
# 3  Anchorage AK
# 4  Augusta GA
# 5  Athens GA
# 6  Ventura CA
# 7  Macon GA
# 8  Methuen MA
# 9  Watertown MA
# 10  Franklin MA
# 11  Butte-Silver Bow MT
# 12  Bethel Park PA
# 13  Monroeville PA
# 14  De Land FL
# 15  La Cada Flintridge CA
# 16  Murrysville PA
# 17  Can City CO
# 18  Cusseta GA
# 19  West Carrollton City OH
# 20  West Paterson NJ
# 21  Espanola NM
# 22  Sitka  and AK
# 23  Anaconda MT
# 24  Hartsville TN
# 25  Islamorada, Village of Islands FL
# 26  Lynchburg TN
# 27  De Funiak Springs FL
# 28  Ranson corporation WV
# 29  Waverly City OH
# 30  McRae GA

# %%
find_missing('McRae')
# Out:
# 766   McRae city, Arkansas  McRae AR
#
# 8645   McRae-Helena city, Georgia  McRae-Helena GA

# %%
nodubs[nodubs.NAME == 'El Paso de Robles (Paso Robles) city, California']
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 1402        2343          2344            2344  1600000US0622300
#
#                                                   NAME  DP02_0001E  \
# 1402  El Paso de Robles (Paso Robles) city, California       11802
#
#       DP02_0001M  DP02_0001PE  DP02_0001PM  DP02_0002E  ...  DP05_0088PE  \
# 1402         433        11802          NaN        8366  ...         46.9
#
#       DP05_0088PM DP05_0089E  DP05_0089M  DP05_0089PE  DP05_0089PM  \
# 1402          1.6      10926         566         53.1          1.6
#
#            state  marker  st       full_name
# 1402  California    city  CA  Paso Robles CA
#
# [1 rows x 2099 columns]

# %%
name = 'El Paso de Robles (Paso Robles) city, California'
nodubs = dropit(name)

# %%
fixname('Easthampton Town MA','Easthampton MA')

# %%
df = nodubs.reindex()

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 0           0             1               1  1600000US0167056
# 1           1             2               2  1600000US0178984
# 2           2             3               3  1600000US0162688
# 3           3             4               4  1600000US0131096
# 4           4             5               5  1600000US0119816
#
#                          NAME  DP02_0001E  DP02_0001M  DP02_0001PE  \
# 0  Russellville city, Alabama        3208         282         3208
# 1          Vina town, Alabama         146          37          146
# 2    Providence town, Alabama         101          29          101
# 3         Grant town, Alabama         367          58          367
# 4      Daviston town, Alabama          93          29           93
#
#    DP02_0001PM  DP02_0002E  ...  DP05_0088PE  DP05_0088PM DP05_0089E  \
# 0          NaN        2195  ...         51.2          4.3       2620
# ...

# %%
nodubs.to_csv('data/nodubs.csv')

# %%
nodubs[nodubs.full_name == "Salt Lake City UT"]
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1            GEO_ID  \
# 17972       26524         26525           26525  1600000US4967000
#
#                             NAME  DP02_0001E  DP02_0001M  DP02_0001PE  \
# 17972  Salt Lake City city, Utah       76876         844        76876
#
#        DP02_0001PM  DP02_0002E  ...  DP05_0088PE  DP05_0088PM DP05_0089E  \
# 17972          NaN       40301  ...         51.5          0.8      64632
#
#        DP05_0089M  DP05_0089PE  DP05_0089PM state  marker  st  \
# 17972        1095         48.5          0.8  Utah    city  UT
#
#                full_name
# 17972  Salt Lake City UT
#
# [1 rows x 2099 columns]

# %%
nodubs.shape
# Out:
# (29131, 2099)

# %%
nodubs.groupby('full_name')['full_name'].count().sort_values()
# Out:
# full_name
# Aaronsburg PA            1
# Onslow IA                1
# Onset MA                 1
# Onley VA                 1
# Onida SD                 1
# Ong NE                   1
# Oneonta NY               1
# Oneonta AL               1
# Onekama MI               1
# Oneida TN                1
# Oneida PA                1
# Oneida NY                1
# Onsted MI                1
# Oneida KY                1
# Oneida IL                1
# Oneida Castle NY         1
# Onaway MI                1
# Onaway ID                1
# Onawa IA                 1
# Onarga IL                1
# Onancock VA              1
# Onamia MN                1
# Onalaska WI              1
# Onalaska WA              1
# Onalaska TX              1
# Oneida KS                1
# Onaka SD                 1
# Ontario CA               1
# Ontario OH               1
# Optima OK                1
#                         ..
# Gem Lake MN              1
# Gene Autry OK            1
# Genesee CO               1
# ...
