  '2014-07': 305839.0,
  '2014-08': 306993.6667,
  '2014-09': 307086.0,
  '2014-10': 309450.3333,
  '2014-11': 312074.0,
  '2014-12': 315192.6667,
  '2015-01': 319103.6667,
  '2015-02': 321950.3333,
  '2015-03': 325440.3333,
  '2015-04': 327937.6667,
  '2015-05': 332819.0,
  '2015-06': 336540.3333,
  '2015-07': 341418.6667,
  '2015-08': 346709.3333,
  '2015-09': 351748.3333,
  '2015-10': 356529.3333,
  '2015-11': 360909.6667,
  '2015-12': 365187.6667,
  '2016-01': 368066.6667,
  '2016-02': 370217.0,
  '2016-03': 373274.3333,
  '2016-04': 376763.3333,
  '2016-05': 381057.0,
  '2016-06': 384950.0,
  '2016-07': 388556.0,
  '2016-08': 390950.3333,
  '2016-09': 393233.3333,
  '2016-10': 396003.0,
  '2016-11': 400244.3333,
  '2016-12': 406498.0,
  '2017-01': 412521.3333,
  '2017-02': 418615.3333,
  '2017-03': 422647.6667,
  '2017-04': 428262.3333,
  '2017-05': 434619.0,
  '2017-06': 442400.6667,
  '2017-07': 450862.6667,
  '2017-08': 458534.3333,
  '2017-09': 465703.3333,
  '2017-10': 470554.3333,
  '2017-11': 472155.3333,
  '2017-12': 474718.0,
  '2018-01': 479998.0,
  '2018-02': 490005.6667,
  '2018-03': 500587.0,
  '2018-04': 508709.3333,
  '2018-05': 511567.0,
  '2018-06': 510714.0,
  '2018-07': 507070.3333,
  '2018-08': 504822.6667,
  '2018-09': 503272.6667,
  '2018-10': 501390.0,
  '2018-11': 498299.6667,
  '2018-12': 494426.6667,
  '2019-01': 491808.6667,
  '2019-02': 489307.6667,
  '2019-03': 487173.3333,
  '2019-04': 483054.0,
  '2019-05': 477777.0,
  '2019-06': 471200.6667,
  '2019-07': 467170.0,
  '2019-08': 465192.0,
  '2019-09': 463644.6667,
  '2019-10': 461613.6667,
  '2019-11': 462258.0}}

# %%
nm = 2312

if nm == 27908:
    housep = house_price["Seattle WA"]
elif nm == 17247:
    housep = house_price['New York NY']
else:
    housep = house_price['Los Angeles CA']
if nm == 27908:
    popg = pop_growth[0]['Seattle city']
elif nm == 17247:
    popg = pop_growth[2]['New York city (pt.)']
else:
    popg = pop_growth[1]['Los Angeles city']

# %%
jsn = {'_id':nm,
       'name':df.NAME[nm],
       'Total Population':df['DP05_0001E'][nm],
       'Population Growth': popg,
       'Population Male & Female':{'Male':df['DP05_0002PE'][nm],'Female':df['DP05_0003PE'][nm]},
       'Age Distribution':{'Under 5':df['DP05_0005PE'][nm],
                           '5 to 9':df['DP05_0006PE'][nm],
                          '10 to 14':df['DP05_0007PE'][nm],
                          '15 to 19':df['DP05_0008PE'][nm],
                          '20 to 24':df['DP05_0009PE'][nm],
                          '25 to 34':df['DP05_0010PE'][nm],
                          '35 to 44':df['DP05_0011PE'][nm],
                          '45 to 54':df['DP05_0012PE'][nm],
                          '55 to 59':df['DP05_0013PE'][nm],
                          '60 to 64':df['DP05_0014PE'][nm],
                          '65 to 74':df['DP05_0015PE'][nm],
                          '75 to 84':df['DP05_0016PE'][nm],
                          '85 years and over':df['DP05_0017PE'][nm]},
       'Median Age': df['DP05_0018E'][nm],
       'Population under 18':df['DP05_0019PE'][nm],
       'Population over 16':df['DP05_0020PE'][nm],
       'Ethnicity':{'White':df['DP05_0077PE'][nm],
                           'Hispanic or Latino':df['DP05_0071PE'][nm],
                          'African American':df['DP05_0078PE'][nm],
                          'American Indian':df['DP05_0079PE'][nm],
                          'Asian':df['DP05_0080PE'][nm],
                          'Pacific Islander':df['DP05_0081PE'][nm],
                          'other race':df['DP05_0082PE'][nm],
                          'Two or more races':df['DP05_0083PE'][nm]},
       'Marital Status':{'Males':{'Never Married':df['DP02_0025PE'][nm],
                                  'Currently Married':df['DP02_0026PE'][nm], 
                                  'Separated':df['DP02_0027PE'][nm], 
                                  'Divorced':df['DP02_0028PE'][nm]},
                        'Females':{'Never Married':df['DP02_0031PE'][nm],
                                  'Currently Married':df['DP02_0032PE'][nm], 
                                  'Separated':df['DP02_0033PE'][nm], 
                                  'Divorced':df['DP02_0034PE'][nm]}
                        },
       'Recent Mothers':{'Total':df['DP02_0036E'][nm],
                        'Birth Rate':{'Avg':df['DP02_0039E'][nm]},
                        'Age Distribution':{'15-19':df['DP02_0040E'][nm],
                                           '20-34':df['DP02_0041E'][nm],
                                           '35-50':df['DP02_0042E'][nm]},
                        'National Avg.':{'15-19':17.29,
                                           '20-34':103.95,
                                           '35-50':19.82}},
       'School Enrollment':{'Preschool':df['DP02_0054PE'][nm],
                           'Elementary':df['DP02_0055PE'][nm],
                           'High school':df['DP02_0056PE'][nm],
                           'College':df['DP02_0057PE'][nm]},
       'Educational Attainment':{'Less than 9th grade':df['DP02_0059PE'][nm],
                           '9th to 12th grade no diploma':df['DP02_0060PE'][nm],
                           'High school':df['DP02_0061PE'][nm],
                           'Some college no degree':df['DP02_0062PE'][nm],
                            "Associate's degree":df['DP02_0063PE'][nm],
                           "Bachelor's degree":df['DP02_0064PE'][nm],
                           'Graduate degree':df['DP02_0065PE'][nm]},
       'Language':{'English Only':df['DP02_0111PE'][nm],
                   'Language other than English':df['DP02_0112PE'][nm],
                  'Cannot Speak English':df['DP02_0113PE'][nm]},
       'Two or more Languages': df['DP02_0112PE'][nm] - df['DP02_0113PE'][nm],
       'Unemployment Rate': df['DP03_0009PE'][nm],
       'Sex of Labor Force': {'Male': 100 - df['DP03_0011PE'][nm], 'Female':df['DP03_0011PE'][nm]}, 
       'Commuting to Work': {'Drives Alone':df['DP03_0019PE'][nm],
                            'Carpools':df['DP03_0020PE'][nm],
                            'Public Transport':df['DP03_0021PE'][nm],
                            'Walks':df['DP03_0022PE'][nm],
                            'Works at home':df['DP03_0024PE'][nm],
                            "Other transport":df['DP03_0023PE'][nm]},
       'Mean Travel Time': float(df['DP03_0025E'][nm]), 
       'Occupation':{'Management business science and arts occupations':df['DP03_0027PE'][nm],
                    'Service occupations':df['DP03_0028PE'][nm],
                    'Sales and office occupations':df['DP03_0029PE'][nm],
                     'Natural resources construction and maintenance occupations':df['DP03_0030PE'][nm]},
       'Industry':{'Agriculture forestry fishing and hunting and mining':df['DP03_0033PE'][nm],
                  'Construction':df['DP03_0034PE'][nm],
                  'Manufacturing':df['DP03_0035PE'][nm],
                  'Wholesale trade':df['DP03_0036PE'][nm],
                  'Retail trade':df['DP03_0037PE'][nm],
                  'Transportation and warehousing and utilities':df['DP03_0038PE'][nm],
                   'Information':df['DP03_0039PE'][nm],
                  'Finance and insurance and real estate and rental and leasing':df['DP03_0040PE'][nm],
                  'Professional scientific and management and administrative and waste management services':df['DP03_0041PE'][nm],
                  'Educational services and health care and social assistance':df['DP03_0042PE'][nm],
                  'Arts entertainment and recreation and accommodation and food services':df['DP03_0043PE'][nm],
                  'Other services except public administration':df['DP03_0044PE'][nm],
                  'Public administration':df['DP03_0045PE'][nm]},
        'Class of Worker':{'Private wage and salary workers':df['DP03_0047PE'][nm],
                          'Government workers':df['DP03_0048PE'][nm],
                          'Self-employed in own not incorporated business workers':df['DP03_0049PE'][nm],
                          'Unpaid family workers':df['DP03_0050PE'][nm]},
       'Household Income':{'Less than $10,000':df['DP03_0052PE'][nm],
                '$10,000 - $14,999':df['DP03_0053PE'][nm],
                '$15,000 - $24,999':df['DP03_0054PE'][nm],
                '$25,000 - $34,999':df['DP03_0055PE'][nm],
                '$35,000 - $49,999':df['DP03_0056PE'][nm],
                '$50,000 - $74,999':df['DP03_0057PE'][nm],
                '$75,000 - $99,999':df['DP03_0058PE'][nm],
                '$100,000 - $149,999':df['DP03_0059PE'][nm],
                '$150,000 - $199,999':df['DP03_0060PE'][nm],
                '$200,000 or more':df['DP03_0061PE'][nm]},
       'Median Household Income':float(df['DP03_0062E'][nm]),
       'Mean Household Income':df['DP03_0063E'][nm],
       'Retirment Percent':{'With Social Security':df['DP03_0066PE'][nm],
                            'With retirement income':df['DP03_0068PE'][nm],
                           'With Supplemental Security Income':df['DP03_0070PE'][nm]},
       'Retirment Avg':{'Mean Social Security income':float(df['DP03_0067E'][nm]),
                        'Mean retirement income':float(df['DP03_0069E'][nm]),
                        'Mean Supplemental Security Income':float(df['DP03_0071E'][nm])},
       'Public Assistance Percent':{'With cash public assistance income':df['DP03_0072PE'][nm],
                                    'With Food Stamp/SNAP benefits':df['DP03_0074PE'][nm]},
       'Median Per Capita Income': df['DP03_0092E'][nm],
       'Per Capitca by Gender':{'Female':df['DP03_0094E'][nm],
                               'Male':df['DP03_0093E'][nm]},
       'Health Insurance':df['DP03_0096PE'][nm],
       'Below Poverty Level':df['DP03_0119PE'][nm],
       'Total Housing Units': df['DP04_0001E'][nm],
       'Occupied Housing Units': {'Occupied Housing Units':df['DP04_0002PE'][nm],'Vacant Housing Units':df['DP04_0003PE'][nm]},
       'Vacancy Rate':{'Homeowner vacancy rate':df['DP04_0004E'][nm],'Rental vacancy rate':df['DP04_0005E'][nm]},
       'Units in Structure': {'1-unit detached':df['DP04_0007PE'][nm],
                             '1-unit attached':df['DP04_0008PE'][nm],
                             '2 units':df['DP04_0009PE'][nm],
                             '3 - 4 units':df['DP04_0010PE'][nm],
                             '5 - 9 units':df['DP04_0011PE'][nm],
                             '10 - 19 units':df['DP04_0012PE'][nm],
                             '20 or more units':df['DP04_0013PE'][nm]},
       'Total housing units':df['DP04_0016E'][nm],
       'Year Built': {'2014 or later':df['DP04_0017PE'][nm],
                     '2010 - 2013':df['DP04_0018PE'][nm],
                     '2000 - 2009':df['DP04_0019PE'][nm],
                     '1990 - 1999':df['DP04_0020PE'][nm],
                     '1980 - 1989':df['DP04_0021PE'][nm],
                     '1970 - 1979':df['DP04_0022PE'][nm],
                     '1960 - 1969':df['DP04_0023PE'][nm],
                     '1950 - 1959':df['DP04_0024PE'][nm],
                     '1940 - 1949':df['DP04_0025PE'][nm],
                     '1939 or earlier':df['DP04_0026PE'][nm]},
       'Houing by rooms':{'1 room':df['DP04_0028PE'][nm],
                     '2 rooms':df['DP04_0029PE'][nm],
                     '3 rooms':df['DP04_0030PE'][nm],
                     '4 rooms':df['DP04_0031PE'][nm],
                     '5 rooms':df['DP04_0032PE'][nm],
                     '6 rooms':df['DP04_0033PE'][nm],
                     '7 rooms':df['DP04_0034PE'][nm],
                     '8 rooms':df['DP04_0035PE'][nm],
                     '9 rooms or more':df['DP04_0036PE'][nm]},
       'Houing by bedrooms':{'No bedrooms':df['DP04_0039PE'][nm],
                     '1 bedroom':df['DP04_0040PE'][nm],
                     '2 bedrooms':df['DP04_0041PE'][nm],
                     '3 bedrooms':df['DP04_0042PE'][nm],
                     '4 bedrooms':df['DP04_0043PE'][nm],
                     '5 bedrooms or more':df['DP04_0044PE'][nm]},
       'Year Moved in':{'2015 or later':df['DP04_0051PE'][nm],
                     '2010 - 2014':df['DP04_0052PE'][nm],
                     '2000 - 2009':df['DP04_0053PE'][nm],
                     '1990 - 1999':df['DP04_0054PE'][nm],
                     '1980 - 1989':df['DP04_0055PE'][nm],
                     '1979 and earlier':df['DP04_0056PE'][nm]},
       'Occupants per room':{'1 or less':df['DP04_0077PE'][nm],
                                  '1 to 1.5':df['DP04_0078PE'][nm],
                                  '1.51 or more':df['DP04_0079PE'][nm]},
       'Vehicles Available':{'No vehicles available':df['DP04_0058PE'][nm],
                     '1 vehicle available':df['DP04_0059PE'][nm],
                     '2 vehicles available':df['DP04_0060PE'][nm],
                     '3 or more vehicles available':df['DP04_0061PE'][nm]},
       'Selected Monthly Owner Costs with Mortgage':{'Less than $500':df['DP04_0094PE'][nm],
                                                    '$500 - $999':df['DP04_0095PE'][nm],
                                                    '$1,000 - $1,499':df['DP04_0096PE'][nm],
                                                    '$1,500 - $1,999':df['DP04_0097PE'][nm],
                                                    '$2,000 - $2,499':df['DP04_0098PE'][nm],
                                                    '$$2,500 - $2,999':df['DP04_0099PE'][nm],
                                                    '$3,000 or more':df['DP04_0100PE'][nm]},
       'Median Selected Monthly Owner Costs with Mortgage':df['DP04_0101E'][nm],
       'Selected Monthly Owner Costs without Mortgage':{'Less than $250':df['DP04_0103PE'][nm],
                                                    '$250 - $399':df['DP04_0104PE'][nm],
                                                    '$400 - $599':df['DP04_0105PE'][nm],
                                                    '$600 - $799':df['DP04_0106PE'][nm],
                                                    '$800 - $999':df['DP04_0107PE'][nm],
                                                    '$1,000 or more':df['DP04_0108PE'][nm]},  
       'Median Selected Monthly Owner Costs without Mortgage':df['DP04_0109E'][nm],
       'Rent': {'Less than $500':df['DP04_0127PE'][nm],
                '$500 - $999':df['DP04_0128PE'][nm],
                '$1,000 - $1,499':df['DP04_0129PE'][nm],
                '$1,500 - $1,999':df['DP04_0130PE'][nm],
                '$2,000 - $2,499':df['DP04_0131PE'][nm],
                '$$2,500 - $2,999':df['DP04_0132PE'][nm],
                '$3,000 or more':df['DP04_0133PE'][nm]},
       'Median Rent':df['DP04_0134E'][nm],
       'house_price':housep
     
       
      }

jsn
# Out:
# {'_id': 2312,
#  'name': 'Los Angeles city, California',
#  'Total Population': 3949776,
#  'Population Growth': {'2010': 4785448,
#   '2011': 4798834,
#   '2012': 4815564,
#   '2013': 4830460,
#   '2014': 4842481,
#   '2015': 4853160,
#   '2016': 4864745,
#   '2017': 4875120,
#   '2018': 4887871},
#  'Population Male & Female': {'Male': 49.5, 'Female': 50.5},
#  'Age Distribution': {'Under 5': 6.2,
#   '5 to 9': 5.9,
#   '10 to 14': 5.7,
#   '15 to 19': 6.3,
#   '20 to 24': 8.0,
#   '25 to 34': 17.6,
#   '35 to 44': 14.5,
#   '45 to 54': 13.3,
#   '55 to 59': 5.9,
#   '60 to 64': 5.0,
#   '65 to 74': 6.5,
#   '75 to 84': 3.5,
#   '85 years and over': 1.7},
#  'Median Age': 35.2,
#  'Population under 18': 21.3,
#  'Population over 16': 81.2,
#  'Ethnicity': {'White': 28.4,
#   'Hispanic or Latino': 48.7,
#   'African American': 8.6,
#   'American Indian': 0.1,
#   'Asian': 11.5,
#   'Pacific Islander': 0.1,
#   'other race': 0.3,
#   'Two or more races': 2.2},
# ...

# %%
import plotly.graph_objects as go
import numpy as np
import pygal

percent_formatter = lambda x: '{:.10g}%'.format(x)
dollar_formatter = lambda x: '{:.10g}$'.format(x)


population = go.Figure(data=[
    go.Bar(name='Males', x=list(jsn['Population Male & Female'].keys()), y=list(jsn['Population Male & Female'].values()))
])

population.update_layout(barmode='group',title='Population Male vs Female')
population.show()

populationgrowth = go.Figure(data=go.Scatter(x=list(jsn['Population Growth'].keys()), y=list(jsn['Population Growth'].values())))
populationgrowth.update_layout(title='Population Growth')
populationgrowth.show()

aged = go.Figure(data=[
    go.Bar(name='Males', x=list(jsn['Age Distribution'].keys()), y=list(jsn['Age Distribution'].values()))
])

aged.update_layout(barmode='group',title='Age Distribution',yaxis_title='% by age')
aged.show()


Ethnicity = go.Figure(data=[
    go.Bar(name='Males', x=list(jsn['Ethnicity'].keys()), y=list(jsn['Ethnicity'].values()))
])

Ethnicity.update_layout(barmode='group',title='Distribution of Ethnicity',yaxis_title='% by Ethnicity')
Ethnicity.show()


marrage_stats = go.Figure(data=[
    go.Bar(name='Males', x=list(jsn['Marital Status']['Males'].keys()), y=list(jsn['Marital Status']['Males'].values())),
    go.Bar(name='Females', x=list(jsn['Marital Status']['Males'].keys()), y=list(jsn['Marital Status']['Males'].values()))
])

marrage_stats.update_layout(barmode='group',title='Marriage Status')
marrage_stats.show()
x = np.arange(10)

print(f'{jsn["name"]} had a total of {jsn["Recent Mothers"]["Total"]} births in the last 12 months.')

births = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Recent Mothers']['Age Distribution'].keys()), y=list(jsn['Recent Mothers']['Age Distribution'].values())),
    go.Bar(name='National Avg.', x=list(jsn['Recent Mothers']['National Avg.'].keys()), y=list(jsn['Recent Mothers']['National Avg.'].values()))
])
births.update_layout(barmode='group',
                     title='Births in the last 12 months per 1,000 women',
                     xaxis_title='Age Distribution',
                    yaxis_title='Births per 1,000 females')
births.show()

      
school = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['School Enrollment'].keys()), y=list(jsn['School Enrollment'].values())),
    
])
school.update_layout(barmode='group',
                     title='Distribution of School Enrollment: Sample from individual three years and older',
                     yaxis_title='% enrolled')
school.show()   
      
attainment = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Educational Attainment'].keys()), y=list(jsn['Educational Attainment'].values())),
    
])
attainment.update_layout(barmode='group',
                     title='Distribution of Educational Attainment: Individuals 25 and older',
                     yaxis_title='% of Education Attained')
language = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Language'].keys()), y=list(jsn['Language'].values())),
    
])
language.update_layout(barmode='group',
                     title='Language',
                     yaxis_title='')
     
bilanguage = go.Figure(go.Indicator(
    mode = "gauge+number",
    value = jsn['Two or more Languages'],
    domain = {'x': [0, 1], 'y': [0, 1]},
    gauge = {'axis': {'range': [None, 100]},

             'threshold' : {'line': {'color': "red", 'width': 4}, 'thickness': 0.75, 'value': 490}},
    title = {'text': "% of population that can speak more than one language"}))
bilanguage.show()

      
labor = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Sex of Labor Force'].keys()), y=list(jsn['Sex of Labor Force'].values())),
    
])
labor.update_layout(barmode='group',
                     title='Gender of Labor Force',
                     yaxis_title='% of gender')
      
transport = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Commuting to Work'].keys()), y=list(jsn['Commuting to Work'].values())),
    
])
transport.update_layout(barmode='group',
                     title='Type of transport when commuting to work',
                     yaxis_title='% per type of transport')
transport.show()

timetravel = go.Figure(go.Indicator(
    mode = "gauge+number",
    value = jsn['Mean Travel Time'],
    domain = {'x': [0, 1], 'y': [0, 1]},
    gauge = {'axis': {'range': [None, 100]},

             'threshold' : {'line': {'color': "red", 'width': 4}, 'thickness': 0.75, 'value': 490}},
    title = {'text': "Avg. time spent cummuting to work per day"}))
timetravel.show()

Occupation = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Occupation'].keys()), y=list(jsn['Occupation'].values())),
    
])
Occupation.update_layout(barmode='group',
                     title='Work force by Occupation',
                     yaxis_title='% per type of Occupation')
Occupation.show()
      
industry = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Industry'].keys()), y=list(jsn['Industry'].values())),
    
])
industry.update_layout(barmode='group',
                     title='Work force by Industry',
                     yaxis_title='% per type of Industry')
industry.show()
      
worker = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Class of Worker'].keys()), y=list(jsn['Class of Worker'].values())),
    
])
worker.update_layout(barmode='group',
                     title='Work force by Class of Worker',
                     yaxis_title='% by Class of Worker')
worker.show()      

income = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Household Income'].keys()), y=list(jsn['Household Income'].values())),
    
])
income.update_layout(barmode='group',
                     title='Household Income: Inflation-adjusted',
                     yaxis_title='% by household income')
income.show() 
      
      
houseincome = go.Figure(go.Indicator(
    mode = "gauge+number",
    value = jsn['Median Household Income'],
    domain = {'x': [0, 1], 'y': [0, 1]},
    gauge = {'axis': {'range': [None, 100000]},

             'threshold' : {'line': {'color': "red", 'width': 4}, 'thickness': 0.75, 'value': 490}},
    title = {'text': "Median Household Income by US $"}))
houseincome.show()
      
houseincomemean = go.Figure(go.Indicator(
    mode = "gauge+number",
    value = jsn['Mean Household Income'],
    domain = {'x': [0, 1], 'y': [0, 1]},
    gauge = {'axis': {'range': [None, 100000]},

             'threshold' : {'line': {'color': "red", 'width': 4}, 'thickness': 0.75, 'value': 490}},
    title = {'text': "Mean Household Income by US $"}))
houseincomemean.show()
      
import pygal 
from IPython.display import SVG, display
      
print('Retirment Stats')      
      
gauge = pygal.SolidGauge(inner_radius=0.70)

gauge.value_formatter = percent_formatter

gauge.add('% With Social Security', [{'value': jsn['Retirment Percent']['With Social Security'], 'max_value': 100}])
gauge.add('% With retirement income', [{'value': jsn['Retirment Percent']['With retirement income'], 'max_value': 100}])
gauge.add('% With Supplemental Security Income', [{'value': jsn['Retirment Percent']['With Supplemental Security Income'], 'max_value': 100}])

percent_formatter = lambda x: '{:.10g}%'.format(x)
dollar_formatter = lambda x: '{:.10g}$'.format(x)
gauge.value_formatter = percent_formatter      

gauge.add('Mean Social Security income', [{'value': jsn['Retirment Avg']['Mean Social Security income'], 'max_value': 50000}],
          formatter=dollar_formatter)      
gauge.add('Mean retirement income', [{'value': jsn['Retirment Avg']['Mean retirement income'], 'max_value': 50000}],
          formatter=dollar_formatter) 
gauge.add('Mean Supplemental Security Income', [{'value': jsn['Retirment Avg']['Mean Supplemental Security Income'], 'max_value': 50000}],
          formatter=dollar_formatter)       
display(SVG(gauge.render(disable_xml_declaration=True)))     
      
      
      
gauge2 = pygal.SolidGauge(inner_radius=0.70)

gauge2.value_formatter = percent_formatter

gauge2.add('% With cash public assistance income', [{'value': jsn['Public Assistance Percent']['With cash public assistance income'], 'max_value': 100}])
gauge2.add('% With Food Stamp/SNAP benefits', [{'value': jsn['Public Assistance Percent']['With Food Stamp/SNAP benefits'], 'max_value': 100}])      

display(SVG(gauge2.render(disable_xml_declaration=True)))
      
      
percapita = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Per Capitca by Gender'].keys()), y=list(jsn['Per Capitca by Gender'].values())),
    
])
percapita.update_layout(barmode='group',
                     title='Percapita income by Gender',
                     yaxis_title='Income in USD')
percapita.show()      
      
      
health = go.Figure(go.Indicator(
    mode = "gauge+number",
    value = jsn['Health Insurance'],
    domain = {'x': [0, 1], 'y': [0, 1]},
    gauge = {'axis': {'range': [None, 100]},

             'threshold' : {'line': {'color': "red", 'width': 4}, 'thickness': 0.75, 'value': 490}},
    title = {'text': "Percentage of population with Health Care Insurance"}))
health.show()
      
      
health = go.Figure(go.Indicator(
    mode = "gauge+number",
    value = jsn['Below Poverty Level'],
    domain = {'x': [0, 1], 'y': [0, 1]},
    gauge = {'axis': {'range': [None, 50]},

             'threshold' : {'line': {'color': "red", 'width': 4}, 'thickness': 0.75, 'value': 490}},
    title = {'text': "Percentage of families below poverty level"}))
health.show()

      
      
housingo = go.Figure(data=[go.Pie(labels=list(jsn['Occupied Housing Units'].keys()), values=list(jsn['Occupied Housing Units'].values()))])
housingo.show()  

      
gauge3 = pygal.SolidGauge(inner_radius=0.70)

gauge3.value_formatter = percent_formatter

gauge3.add('Homeowner vacancy rate', [{'value': jsn['Vacancy Rate']['Homeowner vacancy rate'], 'max_value': 100}])
gauge3.add('Rental vacancy rate', [{'value': jsn['Vacancy Rate']['Rental vacancy rate'], 'max_value': 100}])      

display(SVG(gauge3.render(disable_xml_declaration=True)))

units = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Units in Structure'].keys()), y=list(jsn['Units in Structure'].values())),
    
])
units.update_layout(barmode='group',
                     title='Units per structure',
                     yaxis_title='% by units in structure')
units.show()

year = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Year Built'].keys()), y=list(jsn['Year Built'].values())),
    
])
year.update_layout(barmode='group',
                     title='Houses by year built',
                     yaxis_title='% by year housing structure was built')
year.show()

rooms = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Houing by rooms'].keys()), y=list(jsn['Houing by rooms'].values())),
    
])
rooms.update_layout(barmode='group',
                     title='Houses by number of rooms',
                     yaxis_title='% by rooms in house')
rooms.show()

bedrooms = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Houing by bedrooms'].keys()), y=list(jsn['Houing by bedrooms'].values())),
    
])
bedrooms.update_layout(barmode='group',
                     title='Houses by number of bedrooms',
                     yaxis_title='% by bedrooms in house')
bedrooms.show()

movedin = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Year Moved in'].keys()), y=list(jsn['Year Moved in'].values())),
    
])
movedin.update_layout(barmode='group',
                     title='Year homeowner moved in',
                     yaxis_title='% by year moved in')
movedin.show()

vehicles = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Vehicles Available'].keys()), y=list(jsn['Vehicles Available'].values())),
    
])
vehicles.update_layout(barmode='group',
                     title='Number of Vehicles per household',
                     yaxis_title='% by number of vehicles')
vehicles.show()

inroom = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Occupants per room'].keys()), y=list(jsn['Occupants per room'].values())),
    
])
inroom.update_layout(barmode='group',
                     title='Average number of occupants per room',
                     yaxis_title='% by avg occupant')
inroom.show()

smoc = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Selected Monthly Owner Costs with Mortgage'].keys()), y=list(jsn['Selected Monthly Owner Costs with Mortgage'].values())),
    
])
smoc.update_layout(barmode='group',
                     title='Selected Monthly Owner Costs with Mortgage',
                     yaxis_title='% by (SMOC) ')
smoc.show()

smocm = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Selected Monthly Owner Costs without Mortgage'].keys()), y=list(jsn['Selected Monthly Owner Costs without Mortgage'].values())),
    
])
smocm.update_layout(barmode='group',
                     title='Selected Monthly Owner Costs without Mortgage',
                     yaxis_title='% by (SMOC) ')
smocm.show()

  
      
rent = go.Figure(data=[
    go.Bar(name=jsn['name'], x=list(jsn['Rent'].keys()), y=list(jsn['Rent'].values())),
    
])
rent.update_layout(barmode='group',
                     title='Percentage of rent paid',
                     yaxis_title='% by rent paid')
rent.show()
      
housepp = go.Figure(data=go.Scatter(x=list(jsn['house_price'].keys()), y=list(jsn['house_price'].values())))
housepp.show()
# Out:
# <div>
#
#
#             <div id="55d94eec-409b-4504-911c-3462d36ac73f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("55d94eec-409b-4504-911c-3462d36ac73f")) {
#                     Plotly.newPlot(
#                         '55d94eec-409b-4504-911c-3462d36ac73f',
#                         [{"name": "Males", "type": "bar", "x": ["Male", "Female"], "y": [49.5, 50.5]}],
# ...
