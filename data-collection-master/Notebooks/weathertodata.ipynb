# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/stations-and-data.csv')
df.head()
# Out:
#    Unnamed: 0_x  elevation     mindate     maxdate  latitude  \
# 0             0       89.6  1942-03-01  2020-01-26   32.3347
# 1             0       89.6  1942-03-01  2020-01-26   32.3347
# 2             0      160.0  2008-12-01  2020-01-25   33.5721
# 3             0      119.5  1948-01-01  2020-01-25   32.5161
# 4             0       53.6  2002-08-01  2020-01-25   31.3127
#
#                                    name  datacoverage            station  \
# 0             MERIDIAN KEY FIELD, MS US           1.0  GHCND:USW00013865
# 1             MERIDIAN KEY FIELD, MS US           1.0  GHCND:USW00013865
# 2               TALLADEGA 10 NNE, AL US           1.0  GHCND:USW00073803
# 3  COLUMBUS METROPOLITAN AIRPORT, GA US           1.0  GHCND:USW00093842
# 4                     NEWTON 8 W, GA US           1.0  GHCND:USW00063828
#
#   elevationUnit  longitude  ...  TMIN-AVG-11  TMIN-AVG-12  TMIN-AVG-2  \
# 0        METERS   -88.7442  ...       42.100       41.025      45.275
# 1        METERS   -88.7442  ...       42.100       41.025      45.275
# 2        METERS   -86.0573  ...       38.475       37.475      42.550
# 3        METERS   -84.9422  ...       45.575       43.275      47.025
# 4        METERS   -84.4706  ...       43.600       43.025      45.825
#
#    TMIN-AVG-3  TMIN-AVG-4  TMIN-AVG-5  TMIN-AVG-6  TMIN-AVG-7  TMIN-AVG-8  \
# 0      46.875      52.200      62.100      70.325      72.950      72.875
# 1      46.875      52.200      62.100      70.325      72.950      72.875
# 2      42.825      49.275      59.425      67.000      70.225      69.600
# 3      47.900      54.325      64.500      70.975      73.550      73.325
# 4      46.450      52.125      61.525      68.825      70.625      70.775
#
#    TMIN-AVG-9
# 0      68.750
# 1      68.750
# 2      64.925
# 3      70.025
# 4      66.450
#
# [5 rows x 71 columns]

# %%
import requests

# %%
df.shape
# Out:
# (686, 71)

# %%
#!pip install plotly

import plotly.graph_objects as go

fig = go.Figure(go.Scattermapbox(
    mode = "markers",
    lon = df.longitude.values.tolist(),
    lat = df.latitude.values.tolist(),
    marker = {'size': 11, 'color':'red'}))

fig.add_trace(go.Scattermapbox(
    mode = "markers",
    lon = df.longitude.values.tolist(),
    lat = df.latitude.values.tolist(),
    marker = {'size': 4, 'color':'white'}))

fig.update_layout(
    margin ={'l':0,'t':0,'b':0,'r':0},
    mapbox = {
        'center': {'lon': 10, 'lat': 10},
        'style': "stamen-terrain",
        'center': {'lon': -20, 'lat': -20},
        'zoom': 1})

fig.show()
# Out:
# <div>
#
#
#             <div id="53a9fa45-563d-442d-ad9a-7293472528da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("53a9fa45-563d-442d-ad9a-7293472528da")) {
#                     Plotly.newPlot(
#                         '53a9fa45-563d-442d-ad9a-7293472528da',
#                         [{"lat": [32.3347, 32.3347, 33.5721, 32.5161, 31.3127, 32.2997, 34.7586, 30.68833, 34.64389, 31.86056, 33.56556, 31.7901, 35.03362, 34.5528, 35.5952, 34.6941, 30.47806, 63.8933, 64.4256, 62.9574, 58.4292, 64.5111, 58.6829, 60.785, 55.0455, 57.7511, 65.3139, 61.19, 57.1552, 64.99, 64.8039, 64.6328, 66.17, 55.3473, 61.7161, 61.5961, 61.3465, 67.73167, 53.895, 68.0277, 68.6483, 61.1561, 64.1539, 66.9169, 70.3463, 55.2207, 71.3213, 60.32, 31.42083, 33.81, 33.65, 35.2302, 33.98, 33.62278, 32.85472, 31.5907, 31.4583, 34.86, 32.835, 37.7086, 32.8118, 34.0608, 35.6147, 36.7278, 34.94, 33.68833, 35.8
9611, 41.1213, 41.62333, 41.43333, 41.9855, 42.06800000000001, 43.4258, 39.09, 41.78, 36.32, 41.57, 37.5, 40.36, 38.61, 38.51, 40.9386, 36.31, 37.4, 40.89, 43.22411, 44.32, 42.89351, 43.86434000000001, 39.87327, 40.77898, 40.77944, 33.4, 35.7, 35.78, 31.8727, 31.92056, 33.954440000000005, 36.41, 35.0216, 35.4072, 37.35, 35.5144, 36.7, 31.8944, 36.0, 33.01, 37.72, 36.0167, 33.37, 33.3433, 35.00278, 42.10944, 44.4683, 43.1167, 41.2433, 44.6333, 40.933, 44.38528, 43.1111, 42.0803, 42.2068, 42.9408, 42.74722, 40.87639, 41.3275, 36.0969, 35.9495, 35.016940000000005, 34.2675, 34.90611, 36.9033, 35.8923, 35.1108, 35.52364, 35.42433, 34.18772, 35.2326, 34.73258, 37.1026, 35.4267, 48.37, 47.64583, 46.7716, 46.7994, 48. ...

# %%
prcp = []
snow = []
tavg = []
tmax = []
tmin = []
for i in df.columns.tolist()[11:]:
    cat = i.split('-')[0]
    if cat == 'PRCP':
        prcp.append(i)
    elif cat == 'SNOW':
        snow.append(i)
    elif cat == 'TAVG':
        tavg.append(i)
    elif cat == 'TMAX':
        tmax.append(i)
    else:
        tmin.append(i)

# %%
for a in [prcp, snow, tavg, tmax, tmin]:
    name = a[0].split('-')[0].lower()
    mylist = a
    myorder = [0, 4, 5, 6, 7, 8, 9, 10, 11, 1, 2, 3]
    vars()[name] = [mylist[i] for i in myorder]

# %%
from math import cos, asin, sqrt

def distance(lat1, lon1, lat2, lon2):
    p = 0.017453292519943295
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p)*cos(lat2*p) * (1-cos((lon2-lon1)*p)) / 2
    return 12742 * asin(sqrt(a))

# %%
dflat = df.latitude.values.tolist()
dflon = df.longitude.values.tolist()

# %%
rNuKKxAX3UL59FIt

# %%
# !pip install pymongo[srv]

import pymongo

mongokey =#
client = pymongo.MongoClient(mongokey)
db = client.citydata
table = db.alldata
print('connected to mongodb')
# Out:
# Requirement already satisfied: pymongo[srv] in /home/matthew/anaconda3/lib/python3.7/site-packages (3.10.1)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0; extra == "srv" in /home/matthew/anaconda3/lib/python3.7/site-packages (from pymongo[srv]) (1.16.0)
# connected to mongodb

# %%
mongokey2 = #
client2 = pymongo.MongoClient(mongokey2)
db2 = client2.citydata
table2 = db2.alldata
print('connected to mongodb')
# Out:
# connected to mongodb

# %%
for i in range(29000):
    get = table.find_one({'_id':i})
    lat = get['Latitude']
    lon = get['Longitude']
    dist_li = []
    for loc in range(len(dflon)):
        dist_val = distance(lat, lon, dflat[loc], dflon[loc])
        dist_li.append(dist_val)
    index_min = np.argmin(dist_li)
    
    #print(f"{lat} - {lon} | {df[['latitude']].values[index_min]} - {df[['longitude']].values[index_min]}")
    
    
    tempjsn = {}
    for a in [prcp, snow, tavg, tmax, tmin]:
        cat = a[0].split('-')[0].lower()
        dikeys = a
        divals = df[a].values[index_min].tolist()
        divals_fin = []
        for b in divals:
            if str(b) == 'nan':
                divals_fin.append(None)
            else:
                divals_fin.append(b)
        weatherdi = dict(zip(dikeys, divals_fin))
        tempjsn[cat] = weatherdi
    get['weather'] = tempjsn
    table2.insert_one(get)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-f55b7377e348> in <module>
#       1 for i in range(29000):
#       2     get = table.find_one({'_id':i})
# ----> 3     lat = get['Latitude']
#       4     lon = get['Longitude']
#       5     dist_li = []
#
# TypeError: 'NoneType' object is not subscriptable
